# %%
import numpy as np
import keras
import scipy.io as sio
import pandas as pd
import tensorflow as tf
from sklearn import model_selection
import matplotlib.pyplot as plt 
from keras import layers
#from keras.models import Sequential
from keras.models import model_from_json
from livelossplot.keras import PlotLossesCallback
from IPython.display import clear_output
from keras.utils.vis_utils import plot_model
#from sklearn import preprocessing
#import math

# %%
#keras.backend.clear_session()

# %%
filename = 'MarmousiModel2_Changed.mat'
marmousi_cube = sio.loadmat(filename)

# %% [markdown]
# ### Carregar dados e cubos de Sísmica e Impedância

# %%
VP = marmousi_cube['Vp']
#VS = marmousi_cube['Vs']
#IS = marmousi_cube['IS']
pimpedance = marmousi_cube['IP']
seismic = marmousi_cube['seismic']

WAVELET = marmousi_cube['wavelet']

# %% [markdown]
# ### Parameters

# %%
n_traces = pimpedance.shape[1]

train_wells_loc = np.arange(0,n_traces,135)
all_wells_loc = np.arange(n_traces)

wells_loc = np.array(list(set(all_wells_loc) - set(train_wells_loc)))
valid_wells_loc, unlabed_wells_loc = model_selection.train_test_split(wells_loc,
                                                                      test_size=0.9,
                                                                      train_size=0.1,
                                                                      shuffle=True)
BATCH_SIZE = 10
noise_dim = 700
IMG_SHAPE = (700,1)

# %% [markdown]
# ### Normalizar Sismica

# %%
seismic_norm = seismic.flatten()
ymin = 0
ymax = 1
seismic_norm = (ymax-ymin)*(seismic_norm-np.min(seismic_norm))/(np.max(seismic_norm)-np.min(seismic_norm)) + ymin
seismic_norm = seismic_norm.reshape(seismic.shape)
#seismic_norm = seismic

# %%
pimpedance_norm = pimpedance.flatten()
ymin = 0
ymax = 1
pimpedance_norm = (ymax-ymin)*(pimpedance_norm-np.min(pimpedance_norm))/(np.max(pimpedance_norm)-np.min(pimpedance_norm)) + ymin
pimpedance = pimpedance_norm.reshape(pimpedance.shape)
#seismic_norm = seismic

# %% [markdown]
# ### Visualizar estatísticas

# %%
'''data_info = pd.DataFrame(zip(seismic_norm.flatten(),
                             pimpedance.flatten()),
                         columns=['Seismic CL Stats','PImp CL Stats'])
data_info.describe()'''
# Out:
# "data_info = pd.DataFrame(zip(seismic_norm.flatten(),\n                             pimpedance.flatten()),\n                         columns=['Seismic CL Stats','PImp CL Stats'])\ndata_info.describe()"

# %% [markdown]
# ### Preparar os Dados

# %%
X_train = np.transpose(seismic_norm[:,train_wells_loc])
Y_train = np.transpose(pimpedance[:-1,train_wells_loc])
X_train = np.expand_dims(X_train,axis=(2,3))
Y_train = np.expand_dims(Y_train,axis=(2,3))

X_valid = np.transpose(seismic_norm[:,valid_wells_loc])
Y_valid = np.transpose(pimpedance[:-1,valid_wells_loc])
X_valid = np.expand_dims(X_valid,axis=(2,3))
Y_valid = np.expand_dims(Y_valid,axis=(2,3))

X_test = np.transpose(seismic_norm)
Y_test = np.transpose(pimpedance[:-1,:])
X_test = np.expand_dims(X_test,axis=(2,3))
Y_test = np.expand_dims(Y_test,axis=(2,3))

UNLABED_SEISMIC = np.transpose(seismic_norm[:,unlabed_wells_loc])
UNLABED_SEISMIC = np.expand_dims(UNLABED_SEISMIC,axis=(2,3))

# %%
print('     IP (Y_train) shape: ',Y_train.shape)
print('seismic (X_train) shape: ',X_train.shape)

print('     IP (Y_valid) shape: ',Y_valid.shape)
print('seismic (X_valid) shape: ',X_valid.shape)

print('     IP (Y_test) shape: ',Y_test.shape)
print('seismic (X_test) shape: ',X_test.shape)
# Out:
#      IP (Y_train) shape:  (101, 700, 1, 1)
# seismic (X_train) shape:  (101, 700, 1, 1)
#      IP (Y_valid) shape:  (1350, 700, 1, 1)
# seismic (X_valid) shape:  (1350, 700, 1, 1)
#      IP (Y_test) shape:  (13601, 700, 1, 1)
# seismic (X_test) shape:  (13601, 700, 1, 1)

# %% [markdown]
# ### Visualizar Dados

# %%
fig1, axes1 = plt.subplots(nrows=3, ncols=2, figsize=(15,15))

axes1[0,0].imshow(seismic)
axes1[0,0].set_title("2D crossline seismic")

axes1[0,1].imshow(pimpedance)
axes1[0,1].set_title("2D crossline P-Impedance")

axes1[1,0].imshow(X_train[:,:,0,0])
axes1[1,0].set_title("Input Seismic Train")

axes1[1,1].imshow(Y_train[:,:,0,0])
axes1[1,1].set_title("Output P-Impedance Train")

axes1[2,0].imshow(X_test[:,:,0,0])
axes1[2,0].set_title("Input Seismic Test")
axes1[2,1].imshow(Y_test[:,:,0,0])
axes1[2,1].set_title("Output P-Impedance Test - Ground True")
# Out:
# Text(0.5, 1.0, 'Output P-Impedance Test - Ground True')

# %% [markdown]
# ## Criação e Configuração da Rede

# %% [markdown]
# ### Carregar Modelo Forward

# %%
# load json and create model
json_file = open('forward_model/small/modelnorm_2d_changed.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
forward_model = model_from_json(loaded_model_json)
# load weights into new model
forward_model.load_weights("forward_model/small/modelnorm_2d_changed.h5")
print("Loaded forward model from disk")
# Out:
# Loaded forward model from disk

# %%
test_forward = True
if test_forward:
    predict = forward_model(Y_test[:,:])
    predict = np.transpose(predict[:,:,0].numpy())

# %%
if test_forward:
    trace_id = np.random.randint(predict.shape[1])
    plt.plot(predict[0,:,trace_id])
    plt.plot(X_test[trace_id,:,0])
    plt.show()
predict.shape
# Out:
# (1, 700, 13601)

# %% [markdown]
# ### Create the generator

# %%
def get_generator_model():
    noise = layers.Input(shape=(noise_dim,1,1))

    GEN = layers.Conv2D(filters=16,kernel_size=(300,1),padding='same')(noise)
    GEN = layers.BatchNormalization()(noise)
    GEN = layers.ReLU()(GEN)
    
    GEN = layers.Conv2D(filters=16,kernel_size=(300,1),padding='same')(GEN)
    RB = layers.BatchNormalization()(GEN)
    RB = layers.ReLU()(RB)
    RB = layers.Conv2D(filters=16,kernel_size=(3,1),padding='same')(RB)
    RB = layers.BatchNormalization()(RB)
    RB = layers.Add()([RB,GEN])
    GEN = layers.ReLU()(RB)
    
    GEN = layers.Conv2D(filters=16,kernel_size=(300,1),padding='same')(GEN)
    RB = layers.BatchNormalization()(GEN)
    RB = layers.ReLU()(RB)
    RB = layers.Conv2D(filters=16,kernel_size=(3,1),padding='same')(RB)
    RB = layers.BatchNormalization()(RB)
    RB = layers.Add()([RB,GEN])
    GEN = layers.ReLU()(RB)
    
    GEN = layers.Conv2D(filters=16,kernel_size=(300,1),padding='same')(GEN)
    RB = layers.BatchNormalization()(GEN)
    RB = layers.ReLU()(RB)
    RB = layers.Conv2D(filters=16,kernel_size=(3,1),padding='same')(RB)
    RB = layers.BatchNormalization()(RB)
    RB = layers.Add()([RB,GEN])
    GEN = layers.ReLU()(RB)
        
    GEN = layers.Conv2D(filters=1,kernel_size=(3,1),strides=(1,1),padding='same')(GEN)

    GENmodel = keras.models.Model(inputs=noise,outputs=GEN)
    return GENmodel

# %% [markdown]
# ### Create the discriminator (the critic in the original WGAN)

# %%
def PyramidPoolingModule(inputASSP):
    r1 = layers.Conv2D(filters=32,kernel_size=(3,1),padding='same',dilation_rate=1)(inputASSP)
    r1 = layers.BatchNormalization()(r1)
    r1 = layers.ReLU()(r1)
    r2 = layers.Conv2D(filters=32,kernel_size=(3,1),padding='same',dilation_rate=3)(inputASSP)
    r2 = layers.BatchNormalization()(r2)
    r2 = layers.ReLU()(r2)
    r3 = layers.Conv2D(filters=32,kernel_size=(3,1),padding='same',dilation_rate=5)(inputASSP)
    r3 = layers.BatchNormalization()(r3)
    r3 = layers.ReLU()(r3)
    r4 = layers.Conv2D(filters=32,kernel_size=(3,1),padding='same',dilation_rate=7)(inputASSP)
    r4 = layers.BatchNormalization()(r4)
    r4 = layers.ReLU()(r4)
    assp = layers.concatenate([r1,r2,r3,r4])
    assp = layers.Conv2D(filters=64,kernel_size=(3,1),padding='same',strides=2)(assp)
    return assp

def EncoderBlock(inputEncB):
    ENCN = layers.Conv2D(filters=16,kernel_size=(300,1),padding='same')(inputEncB)
    ENCN = layers.ReLU()(ENCN)
    ENCN = layers.Conv2D(filters=16,kernel_size=(3,1),padding='same')(ENCN)
    ENCN = layers.Add()([ENCN, inputEncB])
    ENCN = layers.MaxPooling2D(pool_size=(1,1),strides=(2,1))(ENCN)
    ENCN = layers.ReLU()(ENCN)
    return ENCN

def Encoder(inputEncoder):
    ENC = layers.Conv2D(filters=16,kernel_size=(300,1),padding='same',strides=2)(inputEncoder)
    ENC = layers.LeakyReLU()(ENC)
    ENC = layers.MaxPooling2D(pool_size=(1,1),strides=(2,1))(ENC)
    ENC = EncoderBlock(ENC)
    ENC = EncoderBlock(ENC)
    ENC = EncoderBlock(ENC)
    return  ENC

def get_discriminator_model():       
        input_disc = layers.Input(shape=(700,1,1))        
        enc_out = Encoder(input_disc)
        assp_out = PyramidPoolingModule(enc_out)
        fc_out = layers.Dense(256,kernel_initializer=tf.keras.initializers.HeNormal())(assp_out)
        lkr_out = layers.LeakyReLU()(fc_out)
        fc2_outFlatten = layers.Flatten()(lkr_out)
        fc2_out = layers.Dense(1,
                               kernel_initializer=tf.keras.initializers.HeNormal(),
                               #activation=keras.activations.sigmoid
                              )(fc2_outFlatten)
        
        DISCmodel = keras.models.Model(inputs=input_disc,outputs=fc2_out)
        return DISCmodel

# %% [markdown]
# ### Create the WGAN-GP model

# %%
little_amout = 1e-8

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=3,
        gp_weight=10.0,
        alpha_weight = 1000,
        beta_weight = 500
    ):
        super(WGAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight
        self.alpha_weight = alpha_weight
        self.beta_weight = beta_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn, imp_loss_fn, seis_loss_fn):
        super(WGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn
        self.imp_loss_fn = imp_loss_fn
        self.seis_loss_fn = seis_loss_fn

    def gradient_penalty(self, batch_size, real_images, fake_images):
        
        # Get the interpolated image
        alpha = tf.random.normal([batch_size, 1, 1,1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff
        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)
       
        #2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        #3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, data):
        noises_input,real_images = data
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        random_latent_vectors = noises_input
        
        for i in range(self.d_steps):
            # Get the latent vector

            with tf.GradientTape() as tape:
                
                fake_images = self.generator(random_latent_vectors, training=True)
                fake_logits = self.discriminator(fake_images, training=True)

                real_logits = self.discriminator(real_images, training=True)

                # discriminator loss
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # gradient penalty:
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                
                d_loss = d_cost + gp * self.gp_weight #+ little_amout

            
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            self.d_optimizer.apply_gradients(zip(d_gradient, self.discriminator.trainable_variables))
        
        #unlabed seismic mini batch:
        unlabed_wells_loc = np.arange(UNLABED_SEISMIC.shape[1])
        np.random.shuffle(unlabed_wells_loc)
        unlabed_batch_idxs = unlabed_wells_loc[0:BATCH_SIZE]
        unlabed_batch = UNLABED_SEISMIC[unlabed_batch_idxs,:,:,:]
        
        with tf.GradientTape() as tape:
            
            generated_images = self.generator(random_latent_vectors, training=True)
            gen_img_logits = self.discriminator(generated_images, training=True)
            
            #Generator loss
            g_cost = self.g_loss_fn(gen_img_logits)
            
            #Impedance loss
            #imp_loss = self.imp_loss_fn(generated_images, real_images)
            imp_loss = tf.keras.metrics.mean_squared_error(generated_images, real_images)
            
            #Seismic loss:
            fake_seis_unlabed = forward_model(self.generator(unlabed_batch,training=True))
            seis_cost = self.seis_loss_fn(fake_seis_unlabed,unlabed_batch)
            #seis_cost = tf.keras.metrics.mean_squared_error(fake_seis_unlabed,unlabed_batch)
            
            g_loss = g_cost + self.alpha_weight * imp_loss + self.beta_weight * seis_cost#+little_amout
            
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(zip(gen_gradient, self.generator.trainable_variables))
        
        return {"d_loss": d_loss, "g_loss": g_loss,"imp_loss":(self.alpha_weight * imp_loss),"seis_loss":(self.beta_weight * seis_cost)}

# %% [markdown]
# ### CallBack

# %%
checkp_callback = keras.callbacks.ModelCheckpoint(filepath='best_model.hdf5',
                                             monitor='imp_loss',
                                             verbose=2,
                                             save_best_only=True,
                                             mode='min')

earlystop_callback =  tf.keras.callbacks.EarlyStopping(monitor='imp_loss', 
            mode='min',
            restore_best_weights=True, 
            verbose=2, 
            patience=600)

nan_callback = tf.keras.callbacks.TerminateOnNaN()

class PlotLosses(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.d_losses = []
        self.g_losses = []
        self.imp_losses = []
        self.seis_losses =[]
        
        self.fig = plt.figure()
        
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        
        self.logs.append(logs)
        self.x.append(self.i)
        self.d_losses.append(logs.get('d_loss'))
        self.g_losses.append(logs.get('g_loss'))
        self.imp_losses.append(logs.get('imp_loss'))
        self.seis_losses.append(logs.get('seis_loss'))
        self.i += 1
        
        clear_output(wait=True) 
        if self.i>50:
            plt.plot(self.x[-100:], self.d_losses[-100:], label="d_loss")
            plt.plot(self.x[-100:], self.g_losses[-100:], label="g_loss")
            plt.plot(self.x[-100:], self.imp_losses[-100:], label="imp_loss")
            plt.plot(self.x[-100:], self.seis_losses[-100:], label="seis_loss")
        else:
            plt.plot(self.x, self.d_losses, label="d_loss")
            plt.plot(self.x, self.g_losses, label="g_loss")
            plt.plot(self.x, self.imp_losses, label="imp_loss")
            plt.plot(self.x, self.seis_losses, label="seis_loss")
        plt.legend()
        plt.show();
        
plot_callback = PlotLosses()

# %% [markdown]
# ### Train the end-to-end model

# %%
g_model = get_generator_model()
#g_model.summary()
#plot_model(g_model, show_shapes=True, show_layer_names=False)
d_model = get_discriminator_model()
#d_model.summary()
#plot_model(d_model, show_shapes=True, show_layer_names=False)
plot_losses = PlotLosses()

# Instantiate the optimizer for both networks
# (learning_rate=0.0002, beta_1=0.5 are recommended)
generator_optimizer = keras.optimizers.Adam(learning_rate=0.001)
discriminator_optimizer = keras.optimizers.Adam(learning_rate = 0.001)
# Define the loss functions for the discriminator,
# which should be (fake_loss - real_loss).
# We will add the gradient penalty later to this loss function.

def discriminator_loss(real_img, fake_img):
    real_loss = tf.reduce_mean(real_img)
    fake_loss = tf.reduce_mean(fake_img)
    return fake_loss - real_loss

# Define the loss functions for the generator.
def generator_loss(fake_img):
    return -tf.reduce_mean(fake_img)

def impedance_loss(fake_imp,real_imp):
    imp_mse = tf.keras.metrics.mean_squared_error(real_imp, fake_imp)
    #imp_mse = tf.reduce_mean(tf.square(real_imp - fake_imp))
    return imp_mse

def seismic_loss(fake_seis,real_seis):
    #fake_seis = forward_model(imp_gen)
    #seis_loss = tf.reduce_mean(tf.square(real_seis - fake_seis))
    seis_loss = tf.keras.metrics.mean_squared_error(real_seis, fake_seis)
    return seis_loss

# Set the number of epochs for trainining.
epochs = 2000

# Instantiate the WGAN model.
wgan = WGAN(
    discriminator=d_model,
    generator=g_model,
    latent_dim=noise_dim,
    discriminator_extra_steps=5,
    alpha_weight = 1000,
    beta_weight = 500,
    gp_weight = 10
)

# Compile the WGAN model.
wgan.compile(
    d_optimizer=discriminator_optimizer,
    g_optimizer=generator_optimizer,
    g_loss_fn=generator_loss,
    d_loss_fn=discriminator_loss,
    imp_loss_fn = impedance_loss,
    seis_loss_fn = seismic_loss
)

# %%
# Start training the model.
wgan.fit(X_train,Y_train,
         shuffle=True,
         batch_size=BATCH_SIZE, 
         epochs=epochs, 
         verbose = 1,
         #callbacks=[checkp_callback]
        )
# Out:
# Epoch 1/2000
# 11/11 [==============================] - 19s 197ms/step - d_loss: -28.6021 - g_loss: 964.5038 - imp_loss: 825.9440 - seis_loss: 115.6197: 1s - d_loss: -15.7446 - g_loss: 1907.7954 - imp_loss: 1679.3691 - seis_loss:
# Epoch 2/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -5.0672 - g_loss: 179.4093 - imp_loss: 135.1660 - seis_loss: 5.52220s - d_loss: -9.7911 - g_loss: 187.8569 - imp_loss: 142.7868 - seis_loss: 5.
# Epoch 3/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -1.6874 - g_loss: 112.8362 - imp_loss: 81.4551 - seis_loss: 7.4088 1s - d_loss: -0.1948 - g_loss: 142.8846 - imp_loss: 108.0592 - seis_loss: 7.92 - ETA: 1s - d_loss: -0.3844 - g_loss: 134.1013 - imp_loss: 100.3950 - seis_loss: 7.9 - ETA: 0s - d_loss: -0.8308 - g_loss: 129.9633 - imp_loss: 96.1960 - seis_loss: 7.99 - ETA: 0s - d_loss: -1.3069 - g_loss: 125.2961 - imp_loss: 91.3115 - seis_loss: 7.82 - ETA: 0s - d_loss: -1.5728 - g_loss: 118.7853 - imp_loss: 86.0416 - seis_loss: 7.60
# Epoch 4/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -2.6621 - g_loss: 66.0907 - imp_loss: 43.1222 - seis_loss: 4.87821s - d_loss: -2.3811 - g_loss: 74.2349 - imp_loss: 49.3378 - seis_ - ETA: 0s - d_loss: -2.2660 - g_loss: 69.8319 - imp_loss: 46.1717 - seis_loss: 5.16 - ETA: 0s - d_loss: -2.2853 - g_loss: 69.0876 - imp_loss: 45.6825 - seis_loss: 5.
# Epoch 5/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -1.6411 - g_loss: 56.6708 - imp_loss: 32.2090 - seis_loss: 3.22851s - d_loss: -2.6850 - g_loss: 61.8152 - imp_loss: 32.8987 - seis_loss: 3. - ETA: 1s - d_loss: -2.1979 - g_loss: 58.4159 - imp_loss: 31.8070 - seis_loss: 3.64 - ETA: 1s - d_loss: -2.1201 - g_loss: 58.1364 - imp_loss: 32.6716 - seis_lo - ETA: 0s - d_loss: -1.6936 - g_loss: 57.3439 - imp_loss: 32.2915 - seis_loss: 3.
# Epoch 6/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -1.0048 - g_loss: 47.2435 - imp_loss: 24.9000 - seis_loss: 2.52131s - d_loss: -0.8637 - g_loss: 47.4886 - imp_loss: 25.4823 - sei
# Epoch 7/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: -0.7756 - g_loss: 38.9604 - imp_loss: 18.9174 - seis_loss: 2.17681s - d_loss: -0.5570 - g_loss: 41.6464 - imp_loss: 20.8544 - seis_loss: 2. - ETA: 0s - d_loss: -0.4857 - g_loss: 41.4290 - imp_loss: 20.9450 - seis_lo
# Epoch 8/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.3518 - g_loss: 38.2192 - imp_loss: 17.6400 - seis_loss: 1.8674
# Epoch 9/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.1336 - g_loss: 35.7015 - imp_loss: 17.7805 - seis_loss: 1.74881s - d_loss: -0.2747 - g_loss: 35.4395 - imp_loss: 18.4795 - seis_loss: 1.67 - ETA: 1s - d_loss: -0.2217 - g_loss: 33.9198 - imp_loss: 17.7862 - seis_loss: 1. - ETA: 0s - d_loss: -0.2454 - g_loss: 32.2961 - imp_loss: 17.3941 - seis_loss: 1.77 - ETA: 0s - d_loss: -0.2272 - g_loss: 33.1304 - imp_loss: 18.0757 - seis_loss: 1.79 - ETA: 0s - d_loss: -0.2349 - g_loss: 33.6194 - imp_loss: 18.0325 - seis_loss: 1.79 - ETA: 0s - d_loss: -0.1811 - g_loss: 34.0017 - imp_loss: 17.8496 - seis_loss:
# Epoch 10/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.1228 - g_loss: 33.5506 - imp_loss: 17.4246 - seis_loss: 1.54951s - d_loss: 0.1910 - g_loss: 36.6196 - imp_loss: 15.3393 - seis_loss: 1.67 - ETA: 1s - d_loss: -0.0591 - g_loss: 33.9495 - imp_loss: 15.5161 - seis_loss:  - ETA: 0s - d_loss: -0.0703 - g_loss: 32.3240 - imp_loss: 15.3307 - seis_loss: 1.59 - ETA: 0s - d_loss: -0.0478 - g_loss: 32.2694 - imp_loss: 15.5306 - seis_loss: 1.57 - ETA: 0s - d_loss: -0.0335 - g_loss: 31.6549 - imp_loss: 15.2923 - seis_loss: 1.
# Epoch 11/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.4931 - g_loss: 24.2589 - imp_loss: 14.3813 - seis_loss: 1.3814 1s - d_loss: -0.1185 - g_loss: 23.7513 - imp_loss: 13.7178 - seis_ - ETA: 0s - d_loss: -0.0467 - g_loss: 23.7715 - imp_loss: 13.6461 - seis_loss: 1
# Epoch 12/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0152 - g_loss: 20.2920 - imp_loss: 12.3777 - seis_loss: 1.2598 1s - d_loss: -0.0717 - g_loss: 19.2365 - imp_loss: 12.1429 - seis_loss: 1.2 - ETA: 1s - d_loss: 0.0916 - g_loss: 19.2982 - imp_loss: 12.1667 - seis_loss
# Epoch 13/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.2307 - g_loss: 21.0784 - imp_loss: 11.8917 - seis_loss: 1.1377s - d_loss: -0.0085 - g_loss: 22.2263 - imp_loss: 9.7545 - seis_loss: 1. - ETA: 0s - d_loss: 0.1458 - g_loss: 21.0897 - imp_loss: 11.1485 - seis_loss: 1.166 - ETA: 0s - d_loss: 0.2253 - g_loss: 22.2930 - imp_loss: 12.5278 - seis_loss: 1.16 - ETA: 0s - d_loss: 0.2403 - g_loss: 21.9439 - imp_loss: 12.3304 - seis_loss: 1.154 - ETA: 0s - d_loss: 0.2458 - g_loss: 21.7720 - imp_loss: 12.3288 - seis_loss: 1.14
# Epoch 14/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0584 - g_loss: 18.3981 - imp_loss: 10.8965 - seis_loss: 1.0565
# Epoch 15/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0963 - g_loss: 18.7903 - imp_loss: 11.6076 - seis_loss: 1.0027 1s - d_loss: -0.1157 - g_loss: 18.4219 - imp_loss: 10.5457 - seis_loss - ETA: 0s - d_loss: -0.0544 - g_loss: 17.9761 - imp_loss: 10.3973 - seis_loss: 1. - ETA: 0s - d_loss: -0.0152 - g_loss: 17.8069 - imp_loss: 10.3019 - seis_loss: 1.0
# Epoch 16/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0554 - g_loss: 17.5468 - imp_loss: 10.1668 - seis_loss: 0.9269s - d_loss: 0.3973 - g_loss: 15.0950 - imp_loss: 9.8829 - seis_loss: 0.99 - ETA: 1s - d_loss: 0.3407 - g_loss: 14.7465 - imp_loss: 9.7672 - seis_loss:  - ETA: 0s - d_loss: 0.1359 - g_loss: 14.5910 - imp_loss: 9.5401 - seis_los
# Epoch 17/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0717 - g_loss: 17.2884 - imp_loss: 9.4459 - seis_loss: 0.8935: 1s - d_loss: 0.1474 - g_loss: 18.6721 - imp_loss: 9.9029 - seis_loss: 0.915 - ETA: 0s - d_loss: 0.0984 - g_loss: 17.7154 - imp_loss: 9.5760 - seis_loss: 0. - ETA: 0s - d_loss: 0.0918 - g_loss: 17.4130 - imp_loss: 9.8856 - seis_loss
# Epoch 18/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.1403 - g_loss: 17.3967 - imp_loss: 9.2148 - seis_loss: 0.8348 1s - d_loss: 0.2090 - g_loss: 18.5881 - imp_loss: 10.1328 - seis_loss: 0.871 - ETA: 1s - d_loss: 0.1964 - g_loss: 18.5726 - imp_loss: 10.3465 - seis_loss: 0.8 - ETA: 0s - d_loss: 0.2154 - g_loss: 17.6907 - imp_loss: 9.8927 - seis_lo
# Epoch 19/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.1335 - g_loss: 16.6776 - imp_loss: 9.7215 - seis_loss: 0.79801s - d_loss: 0.3072 - g_loss: 18.1125 - imp_loss: 8.7834 - seis_loss:  - ETA: 0s - d_loss: 0.2925 - g_loss: 16.1372 - imp_loss: 9.3398 - seis_
# Epoch 20/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.1765 - g_loss: 16.2867 - imp_loss: 8.9453 - seis_loss: 0.7442: 1s - d_loss: 0.2660 - g_loss: 17.3781 - imp_loss: 9.8981 - seis_loss: 0.730 - ETA: 1s - d_loss: 0.1803 - g_loss: 17.9978 - imp_loss: 9.9210 - seis_loss: - ETA: 0s - d_loss: 0.0512 - g_loss: 17.1971 - imp_loss: 9.0591 - seis_loss: 0. - ETA: 0s - d_loss: 0.0916 - g_loss: 16.7647 - imp_loss: 9.1839 - seis_loss: 0.74 - ETA: 0s - d_loss: 0.0988 - g_loss: 16.5521 - imp_loss: 9.1813 - seis_loss: 0.
# Epoch 21/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.2246 - g_loss: 14.6940 - imp_loss: 8.8188 - seis_loss: 0.71441s - d_loss: 0.3349 - g_loss: 16.4722 - imp_loss: 9.3377 - s - ETA: 0s - d_loss: 0.1756 - g_loss: 14.3745 - imp_loss: 8.6469 - seis_loss: 0.
# Epoch 22/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0268 - g_loss: 18.0170 - imp_loss: 11.0570 - seis_loss: 0.71231s - d_loss: -0.0039 - g_loss: 13.7736 - imp_loss: 8.4604 - seis_loss: - ETA: 0s - d_loss: 0.0247 - g_loss: 16.0884 - imp_loss: 8.8781 - seis_loss: 0. - ETA: 0s - d_loss: 0.0493 - g_loss: 15.9455 - imp_loss: 8.7251 - seis_loss: 0.69 - ETA: 0s - d_loss: 0.0666 - g_loss: 15.7595 - imp_loss: 8.6777 - seis_loss: 0.
# Epoch 23/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.3970 - g_loss: 17.6668 - imp_loss: 9.4269 - seis_loss: 0.67231s - d_loss: 0.3068 - g_loss: 14.0857 - imp_loss: 9.8036 -
# Epoch 24/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0180 - g_loss: 18.1078 - imp_loss: 7.8183 - seis_loss: 0.6414: 0s - d_loss: -0.0503 - g_loss: 19.1535 - imp_loss: 7.8293 - seis_loss:
# Epoch 25/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.2130 - g_loss: 16.2201 - imp_loss: 9.2068 - seis_loss: 0.60971s - d_loss: 0.2493 - g_loss: 14.1847 - imp_loss: 8.0721 - seis_loss: 0.63 - ETA: 0s - d_loss: 0.2705 - g_loss: 13.5679 - imp_loss: 8.0620 - seis_loss:  - ETA: 0s - d_loss: 0.2783 - g_loss: 13.3507 - imp_loss: 7.9445 - seis_loss:
# Epoch 26/2000
# 11/11 [==============================] - 2s 179ms/step - d_loss: 0.1419 - g_loss: 22.6956 - imp_loss: 9.4921 - seis_loss: 0.58491s - d_loss: 0.1354 - g_loss: 22.2424 - imp_loss: 8.3014 - seis_loss: 0.60 - ETA: 1s - d_loss: 0.0676 - g_loss: 22.1323 - imp_loss: 8.1398 - seis_loss: 0.59 - ETA: 0s - d_loss: 0.0128 - g_loss: 21.9438 - imp_loss: 7.9506 - seis_loss: 0.59 - ETA: 0s - d_loss: -0.0281 - g_loss: 21.9548 - imp_loss: 7.8610 - seis_loss:
# Epoch 27/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0632 - g_loss: 13.4571 - imp_loss: 7.7603 - seis_loss: 0.5629s - d_loss: 0.1986 - g_loss: 18.5651 - imp_loss: 8.5235 - seis_loss: 0.57 - ETA: 1s - d_loss: 0.0889 - g_loss: 17.5467 - imp_loss: 7.9723 - seis_loss:  - ETA: 0s - d_loss: 0.0526 - g_loss: 15.9232 - imp_loss: 7.9199 - seis_loss: 0. - ETA: 0s - d_loss: 0.0185 - g_loss: 14.9102 - imp_loss: 7.8105 - seis_loss: 0.57 - ETA: 0s - d_loss: 0.0059 - g_loss: 14.2971 - imp_loss: 7.6110 - seis_loss: 0.
# Epoch 28/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.2242 - g_loss: 11.6776 - imp_loss: 8.5614 - seis_loss: 0.57021s - d_loss: 0.2834 - g_loss: 8.8807 - imp_loss: 8.2098 - seis_loss - ETA: 0s - d_loss: 0.1875 - g_loss: 10.0803 - imp_loss: 7.2931 - seis_loss: 0.56 - ETA: 0s - d_loss: 0.1794 - g_loss: 9.9952 - imp_loss: 7.2156 - seis_loss:
# Epoch 29/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: -0.1305 - g_loss: 13.0363 - imp_loss: 7.0664 - seis_loss: 0.5176 1s - d_loss: 0.0349 - g_loss: 10.7296 - imp_loss: 6.0536 - seis_loss: 0.534 - ETA: 1s - d_loss: 0.0580 - g_loss: 11.6277 - imp_loss: 6.9294 - seis_loss: 0 - ETA: 0s - d_loss: -0.0415 - g_loss: 11.9500 - imp_loss: 6.7346 - seis_loss:
# Epoch 30/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.1393 - g_loss: 13.5778 - imp_loss: 6.8099 - seis_loss: 0.53291s - d_loss: 0.1572 - g_loss: 16.7268 - imp_loss: 8.2680 - seis_loss - ETA: 0s - d_loss: 0.2121 - g_loss: 16.1905 - imp_loss: 7.6598 - seis_
# Epoch 31/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0326 - g_loss: 13.1536 - imp_loss: 6.8024 - seis_loss: 0.5062s - d_loss: 0.0932 - g_loss: 9.0701 - imp_loss: 7.4190 - seis_loss: 0.52 - ETA: 0s - d_loss: 0.0424 - g_loss: 10.4989 - imp_loss: 7.3586 - seis_loss: 0.50 - ETA: 0s - d_loss: 0.0042 - g_loss: 10.9998 - imp_loss: 7.1423 - seis_loss: 0.50 - ETA: 0s - d_loss: -0.0146 - g_loss: 11.6438 - imp_loss: 7.0712 - seis_loss: 0.
# Epoch 32/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0935 - g_loss: 14.3285 - imp_loss: 7.8014 - seis_loss: 0.48171s - d_loss: 0.1341 - g_loss: 14.3853 - imp_loss: 6.8584 - seis_loss: 0.47 - ETA: 1s - d_loss: 0.1277 - g_loss: 14.3891 - imp_loss: 6.9227 - seis_loss - ETA: 0s - d_loss: 0.0912 - g_loss: 13.3695 - imp_loss: 6.7460 - seis_loss
# Epoch 33/2000
# 11/11 [==============================] - 2s 179ms/step - d_loss: -7.3461e-04 - g_loss: 12.5468 - imp_loss: 6.1124 - seis_loss: 0.4627d_loss: -0.0221 - g_loss: 14.7636 - imp_loss: 6.7782 - seis_loss: 0.457 - ETA: 1s - d_loss: -0.0061 - g_loss: 14.0791 - imp_loss: 6.0639 - seis_loss: 0 - ETA: 0s - d_loss: -0.0209 - g_loss: 13.0219 - imp_loss: 6.1004 - seis_loss: 0.
# Epoch 34/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.1458 - g_loss: 15.0430 - imp_loss: 6.0014 - seis_loss: 0.46511s - d_loss: 0.3266 - g_loss: 16.4308 - imp_loss: 5.9121 - seis_ - ETA: 0s - d_loss: 0.1983 - g_loss: 15.6922 - imp_loss: 6.4284 - seis_loss:
# Epoch 35/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0579 - g_loss: 16.4648 - imp_loss: 7.7386 - seis_loss: 0.46891s - d_loss: 0.0980 - g_loss: 17.0239 - imp_loss: 8.3441 - sei - ETA: 0s - d_loss: 0.0273 - g_loss: 15.3200 - imp_loss: 6.9410 - seis_loss:
# Epoch 36/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: -0.0394 - g_loss: 14.6674 - imp_loss: 6.4738 - seis_loss: 0.4291 1s - d_loss: -0.0628 - g_loss: 14.8502 - imp_loss: 6.8842 - seis_lo
# Epoch 37/2000
# 11/11 [==============================] - 2s 179ms/step - d_loss: 0.0884 - g_loss: 12.1277 - imp_loss: 7.5838 - seis_loss: 0.42510s - d_loss: 0.1124 - g_loss: 10.1281 - imp_loss: 5.6490 - seis_loss:
# Epoch 38/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0561 - g_loss: 13.6162 - imp_loss: 6.3831 - seis_loss: 0.4108s - d_loss: 0.0095 - g_loss: 10.3782 - imp_loss: 5.8114 - seis_loss: 0 - ETA: 0s - d_loss: -0.0418 - g_loss: 12.0036 - imp_loss: 5.7602 - seis_loss:
# Epoch 39/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0113 - g_loss: 11.9201 - imp_loss: 6.1279 - seis_loss: 0.40761s - d_loss: 0.0555 - g_loss: 13.5534 - imp_loss: 6.5866 - seis_loss: 0.41 - ETA: 1s - d_loss: 0.1214 - g_loss: 14.4492 - imp_loss: 7.6213 - seis_lo - ETA: 0s - d_loss: 0.0482 - g_loss: 12.5191 - imp_loss: 6.2470 - seis_loss: 0.40 - ETA: 0s - d_loss: 0.0377 - g_loss: 12.4711 - imp_loss: 6.2778 - seis_loss:
# Epoch 40/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.1798 - g_loss: 12.2082 - imp_loss: 5.9286 - seis_loss: 0.38891s - d_loss: -0.0190 - g_loss: 10.8965 - imp_loss: 5.6245 - seis_loss: 0.384 - ETA: 1s - d_loss: 0.0032 - g_loss: 11.8964 - imp_loss: 6.0337 - seis_loss: 0.3 - ETA: 1s - d_loss: 0.0057 - g_loss: 12.7731 - imp_loss: 5.8169 - seis_loss: 0.38 - ETA: 0s - d_loss: 0.0192 - g_loss: 13.0988 - imp_loss: 5.8100 - seis_loss:  - ETA: 0s - d_loss: 0.0099 - g_loss: 12.7447 - imp_loss: 5.4442 - seis_loss:
# Epoch 41/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0955 - g_loss: 7.7049 - imp_loss: 5.8957 - seis_loss: 0.3788 0s - d_loss: 0.0905 - g_loss: 8.1977 - imp_loss: 6.0202 - seis_loss: 0.386 - ETA: 0s - d_loss: 0.0907 - g_loss: 8.0975 - imp_loss: 6.0957 - seis_loss: 0.38
# Epoch 42/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0253 - g_loss: 8.4991 - imp_loss: 6.4519 - seis_loss: 0.3695ETA: 1s - d_loss: 0.0050 - g_loss: 6.0271 - imp_loss: 4.5710 - seis_loss: 0.3716   - ETA: 0s - d_loss: -7.0979e-06 - g_loss: 5.8817 - imp_loss: 5.0729 - seis_lo
# Epoch 43/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0057 - g_loss: 9.6024 - imp_loss: 5.3373 - seis_loss: 0.3616 1s - d_loss: 0.0072 - g_loss: 9.2100 - imp_loss: 5.1667 - seis_loss: 0 - ETA: 0s - d_loss: 0.0023 - g_loss: 9.5506 - imp_loss: 5.1863 - seis_loss: 0.
# Epoch 44/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0662 - g_loss: 3.9723 - imp_loss: 5.3032 - seis_loss: 0.3540 0s - d_loss: 0.0843 - g_loss: 4.5315 - imp_loss: 5.0632 - seis_loss: 0. - ETA: 0s - d_loss: 0.0692 - g_loss: 3.9394 - imp_loss: 5.1162 - seis_loss: 0.35
# Epoch 45/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0212 - g_loss: 3.3512 - imp_loss: 4.9092 - seis_loss: 0.3422 1s - d_loss: 0.0153 - g_loss: 2.2967 - imp_loss: 5.0403 - seis_loss: 0 - ETA: 0s - d_loss: -0.0149 - g_loss: 3.2861 - imp_loss: 4.6294 - seis_loss: 0.3 - ETA: 0s - d_loss: 0.0075 - g_loss: 3.7446 - imp_loss: 4.8727 - seis_loss: 0.3472
# Epoch 46/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.0165 - g_loss: 5.1544 - imp_loss: 5.7230 - seis_loss: 0.3355A: 0s - d_loss: -0.0140 - g_loss: 2.0832 - imp_loss: 4.7872 - seis_loss: 0.33 - ETA: 0s - d_loss: -0.0215 - g_loss: 2.3962 - imp_loss: 4.7745 - seis_loss: 0.33 - ETA: 0s - d_loss: -0.0302 - g_loss: 3.0169 - imp_loss: 4.9113 - seis_loss
# Epoch 47/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0302 - g_loss: 5.0526 - imp_loss: 4.8356 - seis_loss: 0.33251s - d_loss: 0.0138 - g_loss: 6.7993 - imp_loss: 5.5770 - seis_loss:  - ETA: 0s - d_loss: -0.0141 - g_loss: 6.4639 - imp_loss: 5.2171 - seis_loss
# Epoch 48/2000
# 11/11 [==============================] - 2s 185ms/step - d_loss: 0.0227 - g_loss: 2.2926 - imp_loss: 4.7768 - seis_loss: 0.3210A: 1s - d_loss: 0.0288 - g_loss: -0.3862 - imp_loss: 4.6878 - seis_loss: 0.327 - ETA: 1s - d_loss: 0.0229 - g_loss: -0.5764 - imp_loss: 4.4675 - seis_loss: 0.32 - ETA: 1s - d_loss: 0.0053 - g_loss: -0.3868 - imp_loss: 4.3736 - seis_loss: - ETA: 0s - d_loss: 0.0377 - g_loss: 1.8070 - imp_loss: 4.8575 - seis_loss: 0.32
# Epoch 49/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0142 - g_loss: 6.5376 - imp_loss: 4.8890 - seis_loss: 0.31211s - d_loss: 0.0225 - g_loss: 5.8192 - imp_loss: 4.7958 - seis_loss: 0.31 - ETA: 0s - d_loss: 0.0055 - g_loss: 5.6416 - imp_loss: 4.5445 - seis_loss: 0.3 - ETA: 0s - d_loss: 0.0024 - g_loss: 5.8688 - imp_loss: 4.6072 - seis_loss: 0.3131 - ETA: 0s - d_loss: 0.0042 - g_loss: 6.0065 - imp_loss: 4.6256 - seis_loss: 0.3
# Epoch 50/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0559 - g_loss: 3.1668 - imp_loss: 4.3974 - seis_loss: 0.3089 1s - d_loss: 0.0599 - g_loss: 7.9878 - imp_loss: 4.5698 - seis_loss: 0.30 - ETA: 1s - d_loss: 0.0840 - g_loss: 5.9498 - imp_loss: 4.4531 - seis_loss: 0. - ETA: 0s - d_loss: 0.0686 - g_loss: 3.5175 - imp_loss: 4.5408 - seis_loss: 0.
# Epoch 51/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0880 - g_loss: 8.7989 - imp_loss: 5.2171 - seis_loss: 0.3086 1s - d_loss: 0.0558 - g_loss: 5.9301 - imp_loss: 5.2524 - seis_loss: 0 - ETA: 0s - d_loss: 0.0309 - g_loss: 7.9910 - imp_loss: 4.5946 - seis_loss: 0.3
# Epoch 52/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0213 - g_loss: 8.0694 - imp_loss: 4.4726 - seis_loss: 0.29611s - d_loss: -0.0081 - g_loss: 7.7270 - imp_loss: 4.6445 - seis_loss: 0.29 - ETA: 1s - d_loss: -0.0078 - g_loss: 7.9347 - imp_loss: 4.4813 - seis_loss: 0.29 - ETA: 1s - d_loss: -0.0015 - g_loss: 8.2958 - imp_loss: 4.4765 - seis_loss: 0.29 - ETA: 0s - d_loss: -7.0055e-04 - g_loss: 8.5531 - imp_loss: 4.6082 - seis_los
# Epoch 53/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0131 - g_loss: 7.9753 - imp_loss: 4.3362 - seis_loss: 0.2983: 1s - d_loss: 0.0272 - g_loss: 9.1637 - imp_loss: 4.3275 - seis_loss: 0.303 - ETA: 1s - d_loss: 0.0226 - g_loss: 9.2008 - imp_loss: 4.7368 - seis_loss: 0. - ETA: 0s - d_loss: 0.0378 - g_loss: 8.8854 - imp_loss: 4.6947 - seis_loss: 0.2
# Epoch 54/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0032 - g_loss: 2.7883 - imp_loss: 4.6020 - seis_loss: 0.2884
# Epoch 55/2000
# 11/11 [==============================] - 2s 179ms/step - d_loss: 0.1144 - g_loss: 8.6656 - imp_loss: 4.6021 - seis_loss: 0.2835 1s - d_loss: 0.2199 - g_loss: 9.2067 - imp_loss: 4.9172 - seis_loss: 0.27 - ETA: 1s - d_loss: 0.2264 - g_loss: 9.4513 - imp_loss: 4.5697 - seis_loss
# Epoch 56/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0371 - g_loss: 5.1449 - imp_loss: 4.2570 - seis_loss: 0.2754 1s - d_loss: -0.0079 - g_loss: 7.5095 - imp_loss: 3.6228 - seis_loss: 0.2 - ETA: 0s - d_loss: -0.0013 - g_loss: 6.3851 - imp_loss: 3.6821 - seis_loss: 0. - ETA: 0s - d_loss: 0.0132 - g_loss: 5.6101 - imp_loss: 4.2936 - seis_loss: 0.2
# Epoch 57/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0771 - g_loss: 4.7819 - imp_loss: 4.7744 - seis_loss: 0.2696 1s - d_loss: 0.0852 - g_loss: 3.9184 - imp_loss: 3.9711 - seis_loss: 0.27 - ETA: 0s - d_loss: 0.0741 - g_loss: 3.9769 - imp_loss: 4.1024 - seis_loss: 0.27 - ETA: 0s - d_loss: 0.0571 - g_loss: 3.9944 - imp_loss: 4.1379 - seis_loss: 0.2
# Epoch 58/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: -0.0262 - g_loss: 8.1745 - imp_loss: 3.8248 - seis_loss: 0.26551s - d_loss: 0.0257 - g_loss: 8.5335 - imp_loss: 4.3806 - seis_loss: 0.2 - ETA: 0s - d_loss: -0.0231 - g_loss: 9.9648 - imp_loss: 4.3591 - seis_loss - ETA: 0s - d_loss: -0.0287 - g_loss: 9.0449 - imp_loss: 4.0739 - seis_loss: 0.
# Epoch 59/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0258 - g_loss: -2.9897 - imp_loss: 3.9362 - seis_loss: 0.27110s - d_loss: 0.0472 - g_loss: -1.9147 - imp_loss: 4.1925 - seis_lo
# Epoch 60/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0139 - g_loss: 6.1952 - imp_loss: 3.9919 - seis_loss: 0.2623A: 1s - d_loss: -0.0143 - g_loss: -1.9657 - imp_loss: 3.9671 - seis_loss:  - ETA: 0s - d_loss: -0.0363 - g_loss: 3.2326 - imp_loss: 4.2081 - seis_loss: 0.26 - ETA: 0s - d_loss: -0.0309 - g_loss: 4.1654 - imp_loss: 4.1941 - seis_loss: 0.25 - ETA: 0s - d_loss: -0.0245 - g_loss: 4.7579 - imp_loss: 4.1726 - seis_loss: 0. - ETA: 0s - d_loss: 0.0147 - g_loss: 5.5883 - imp_loss: 4.0851 - seis_loss: 0.260
# Epoch 61/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0134 - g_loss: 11.1798 - imp_loss: 3.7228 - seis_loss: 0.25221s - d_loss: 0.1488 - g_loss: 15.6604 - imp_loss: 4.2625 - seis_loss: 0. - ETA: 1s - d_loss: 0.1068 - g_loss: 14.1083 - imp_loss: 3.9016 - seis_loss: 0.25 - ETA: 1s - d_loss: 0.0932 - g_loss: 13.4354 - imp_loss: 3.9604 - seis_loss: 0. - ETA: 0s - d_loss: 0.0618 - g_loss: 12.0277 - imp_loss: 3.9249 - seis_lo
# Epoch 62/2000
# 11/11 [==============================] - 2s 185ms/step - d_loss: 0.0222 - g_loss: 7.6020 - imp_loss: 3.7756 - seis_loss: 0.2551: 0s - d_loss: 0.0356 - g_loss: 9.2473 - imp_loss: 4.1394 - seis_loss: 0.
# Epoch 63/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0761 - g_loss: 3.0735 - imp_loss: 4.4351 - seis_loss: 0.2490
# Epoch 64/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0136 - g_loss: 9.9790 - imp_loss: 4.3503 - seis_loss: 0.24410s - d_loss: 0.0032 - g_loss: 9.1763 - imp_loss: 4.3052 - seis_loss: 0.248 - ETA: 0s - d_loss: 0.0047 - g_loss: 9.4981 - imp_loss: 4.3492 - seis_loss: 0
# Epoch 65/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.0264 - g_loss: 1.2559 - imp_loss: 3.4820 - seis_loss: 0.2456: 1s - d_loss: 0.0945 - g_loss: 2.5115 - imp_loss: 4.1157 - sei
# Epoch 66/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0059 - g_loss: 8.1308 - imp_loss: 4.2469 - seis_loss: 0.2423: 0s - d_loss: 0.0213 - g_loss: 9.6408 - imp_loss: 3.9648 - seis_loss: 0.24 - ETA: 0s - d_loss: 0.0277 - g_loss: 8.7310 - imp_loss: 4.0051 - seis_loss: 0.24
# Epoch 67/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0592 - g_loss: 6.7417 - imp_loss: 3.8053 - seis_loss: 0.2325
# Epoch 68/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0149 - g_loss: 3.2365 - imp_loss: 3.6114 - seis_loss: 0.2329: 1s - d_loss: -0.0366 - g_loss: 12.5891 - imp_loss: 4.3393 - seis_loss: 0. - ETA: 0s - d_loss: -0.0476 - g_loss: 8.8204 - imp_loss: 3.9205 - seis_loss: 0. - ETA: 0s - d_loss: -0.0285 - g_loss: 7.3968 - imp_loss: 3.6829 - seis_loss
# Epoch 69/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0384 - g_loss: 7.8614 - imp_loss: 3.8819 - seis_loss: 0.23050s - d_loss: 0.0223 - g_loss: 6.8098 - imp_loss: 3.7504 - seis_loss: 0
# Epoch 70/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0725 - g_loss: 0.6463 - imp_loss: 3.7135 - seis_loss: 0.2257 1s - d_loss: 0.1142 - g_loss: 3.9199 - imp_loss: 4.0473 - seis_loss: 0.231 - ETA: 1s - d_loss: 0.0926 - g_loss: 3.3389 - imp_loss: 4.1052 - seis_loss
# Epoch 71/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0265 - g_loss: 0.4275 - imp_loss: 3.4319 - seis_loss: 0.2232: 1s - d_loss: -0.0319 - g_loss: -2.0196 - imp_loss: 3.2061 - seis_loss: 0. - ETA: 1s - d_loss: 0.0326 - g_loss: -2.8052 - imp_loss: 3.5616 - seis_loss: 0.22 - ETA: 0s - d_loss: 0.0287 - g_loss: -2.8262 - imp_loss: 3.5488 - seis_loss: 0.22 - ETA: 0s - d_loss: 0.0237 - g_loss: -2.5396 - imp_loss: 3.5903 - seis_los
# Epoch 72/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0095 - g_loss: 5.0487 - imp_loss: 3.5292 - seis_loss: 0.2171 1s - d_loss: -0.0765 - g_loss: 8.6890 - imp_loss: 3.5484 - sei
# Epoch 73/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 6.5653e-04 - g_loss: 3.6543 - imp_loss: 3.8897 - seis_loss: 0.2110- d_loss: 0.0162 - g_loss: -1.7062 - imp_loss: 3.7511 - seis_loss: 0.21 - ETA: 1s - d_loss: 0.0075 - g_loss: -1.5494 - imp_loss: 3.5469 - se
# Epoch 74/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0205 - g_loss: 5.8433 - imp_loss: 3.6611 - seis_loss: 0.2095 1s - d_loss: 0.1217 - g_loss: 13.4269 - imp_loss: 3.0903 - seis_loss - ETA: 0s - d_loss: 0.0638 - g_loss: 7.7208 - imp_loss: 3.3212 - seis_loss: 0.
# Epoch 75/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0157 - g_loss: 0.2942 - imp_loss: 4.5602 - seis_loss: 0.20921s - d_loss: 0.0355 - g_loss: -1.5263 - imp_loss: 3.8124 - seis_loss: 0. - ETA: 0s - d_loss: 0.0288 - g_loss: -1.4962 - imp_loss: 3.5708 - seis_lo
# Epoch 76/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0918 - g_loss: 7.7819 - imp_loss: 4.6511 - seis_loss: 0.2142 1s - d_loss: 0.0361 - g_loss: 5.5724 - imp_loss: 3.7796 - seis_loss:
# Epoch 77/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0057 - g_loss: 3.7295 - imp_loss: 3.2434 - seis_loss: 0.21171s - d_loss: 0.1139 - g_loss: 3.9158 - imp_loss: 3.9422 - seis_loss: 0.216 - ETA: 1s - d_loss: 0.0754 - g_loss: 3.1423 - imp_loss: 3.9449 - seis_loss: 0.21 - ETA: 1s - d_loss: 0.0237 - g_loss: 1.7530 - imp_loss: 3.9877 - seis_l
# Epoch 78/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.0492 - g_loss: 5.9212 - imp_loss: 4.3070 - seis_loss: 0.2147 1s - d_loss: 0.1110 - g_loss: -0.8149 - imp_loss: 4.1682 - seis_loss: 0. - ETA: 0s - d_loss: 0.0733 - g_loss: 1.5471 - imp_loss: 3.9918 - seis_loss: 0.
# Epoch 79/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: -5.1125e-04 - g_loss: 3.1373 - imp_loss: 4.6941 - seis_loss: 0.2055
# Epoch 80/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0104 - g_loss: 6.4100 - imp_loss: 4.3451 - seis_loss: 0.2075: 1s - d_loss: 0.0375 - g_loss: -0.6792 - imp_loss: 3.8600 - s
# Epoch 81/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0033 - g_loss: 0.7437 - imp_loss: 3.7237 - seis_loss: 0.1976 1s - d_loss: 0.1189 - g_loss: 4.7454 - imp_loss: 3.7116 - seis_los
# Epoch 82/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.1420 - g_loss: -5.0533 - imp_loss: 3.5107 - seis_loss: 0.20241s - d_loss: 0.2556 - g_loss: -3.2037 - imp_loss: 3.8856 - seis_loss: 0.20 - ETA: 1s - d_loss: 0.2023 - g_loss: -4.1292 - imp_loss: 3.8362 -
# Epoch 83/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0223 - g_loss: 7.2212 - imp_loss: 3.0934 - seis_loss: 0.1936: 1s - d_loss: -0.0045 - g_loss: 6.0473 - imp_loss: 3.4409 - seis_loss:  - ETA: 0s - d_loss: 0.0310 - g_loss: 8.7446 - imp_loss: 3.3696 - seis_loss: 0.193 - ETA: 0s - d_loss: 0.0303 - g_loss: 8.6742 - imp_loss: 3.4364 - seis_loss: 0.19 - ETA: 0s - d_loss: 0.0312 - g_loss: 7.8707 - imp_loss: 3.2582 - seis_loss: 0.19
# Epoch 84/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.0629 - g_loss: 4.5955 - imp_loss: 3.9563 - seis_loss: 0.1873 1s - d_loss: 0.0885 - g_loss: 6.2477 - imp_loss: 4.0908 - seis_loss: 0.19 - ETA: 1s - d_loss: 0.0662 - g_loss: 4.7669 - imp_loss: 3.6793 - seis_loss: 0.19 - ETA: 0s - d_loss: 0.0296 - g_loss: 4.0931 - imp_loss: 3.5340 - seis_loss: 0.190 - ETA: 0s - d_loss: 0.0397 - g_loss: 3.7119 - imp_loss: 3.3771 - seis_loss: 0
# Epoch 85/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0154 - g_loss: 6.6336 - imp_loss: 3.2121 - seis_loss: 0.1851 0s - d_loss: -0.0121 - g_loss: 8.8665 - imp_loss: 3.3062 - seis_loss: 0.18 - ETA: 0s - d_loss: -0.0295 - g_loss: 8.6601 - imp_loss: 3.2368 - seis_loss: 0. - ETA: 0s - d_loss: -0.0307 - g_loss: 8.0041 - imp_loss: 3.2655 - seis_loss:
# Epoch 86/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0154 - g_loss: -4.5650 - imp_loss: 3.2712 - seis_loss: 0.18740s - d_loss: 0.0566 - g_loss: -3.3267 - imp_loss: 3.3382 - seis_loss:  - ETA: 0s - d_loss: 0.0266 - g_loss: -4.3524 - imp_loss: 3.2715 - seis_loss: 0.18 - ETA: 0s - d_loss: 0.0289 - g_loss: -4.4751 - imp_loss: 3.2313 - seis_loss: 0.
# Epoch 87/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: -0.0094 - g_loss: 3.3958 - imp_loss: 3.9152 - seis_loss: 0.1826: 1s - d_loss: -0.0605 - g_loss: -2.1918 - imp_loss: 3.1705 - seis_loss: - ETA: 0s - d_loss: -0.0449 - g_loss: 1.6001 - imp_loss: 2.9904 - seis_loss: 0.
# Epoch 88/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0291 - g_loss: -0.2032 - imp_loss: 4.1616 - seis_loss: 0.18651s - d_loss: 0.0379 - g_loss: 6.0313 - imp_loss: 3.4247 - seis_loss: 0.19 - ETA: 1s - d_loss: 0.0433 - g_loss: 2.8733 - imp_loss: 3.0713 - seis_loss: 0.194 - ETA: 1s - d_loss: 0.0351 - g_loss: 1.7616 - imp_loss: 3.1924 - seis_loss: 0.19 - ETA: 0s - d_loss: 0.0307 - g_loss: 0.3669 - imp_loss: 3.1266 - seis_loss: 0.189 - ETA: 0s - d_loss: 0.0189 - g_loss: -0.2179 - imp_loss: 3.0830 - seis_loss
# Epoch 89/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: -0.0180 - g_loss: 0.4018 - imp_loss: 3.4325 - seis_loss: 0.1772: 1s - d_loss: -0.0392 - g_loss: -1.0111 - imp_loss: 3.0443 - seis_loss: 0. - ETA: 0s - d_loss: 0.0015 - g_loss: -0.1999 - imp_loss: 2.8335 - seis_loss: 0.178 - ETA: 0s - d_loss: 0.0112 - g_loss: -0.1687 - imp_loss: 2.8025 - seis_loss: 0. - ETA: 0s - d_loss: 0.0069 - g_loss: -0.2178 - imp_loss: 2.8918 - seis_loss:
# Epoch 90/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0131 - g_loss: 4.1109 - imp_loss: 2.8047 - seis_loss: 0.18061s - d_loss: -0.0213 - g_loss: 6.2197 - imp_loss: 3.3022 - seis_loss - ETA: 0s - d_loss: -0.0289 - g_loss: 6.9711 - imp_loss: 3.1712 - seis_loss
# Epoch 91/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0263 - g_loss: -7.7193 - imp_loss: 2.8430 - seis_loss: 0.17081s - d_loss: 0.0696 - g_loss: -4.8291 - imp_loss: 2.6056 - seis_loss: 0.17 - ETA: 1s - d_loss: 0.0479 - g_loss: -5.2487 - imp_loss: 2.8373 - seis_loss: 0. - ETA: 1s - d_loss: 0.0378 - g_loss: -6.4101 - imp_loss: 2.8460 - seis_loss: 0.17 - ETA: 0s - d_loss: 0.0340 - g_loss: -6.9790 - imp_loss: 2.8068 - seis_loss: 0. - ETA: 0s - d_loss: 0.0348 - g_loss: -8.1503 - imp_loss: 2.7462 - seis_loss: 0. - ETA: 0s - d_loss: 0.0324 - g_loss: -8.1856 - imp_loss: 2.8919 - seis_loss: 0.
# Epoch 92/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0204 - g_loss: 4.7272 - imp_loss: 2.8333 - seis_loss: 0.1702: 1s - d_loss: 0.0356 - g_loss: -1.2639 - imp_loss: 2.8004 - seis_loss - ETA: 0s - d_loss: 0.0293 - g_loss: 3.7555 - imp_loss: 2.9182 - seis_loss: 0.17
# Epoch 93/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: -0.0137 - g_loss: 1.0249 - imp_loss: 2.6239 - seis_loss: 0.16431s - d_loss: 4.0255e-05 - g_loss: 1.1294 - imp_loss: 2.7568 - seis_
# Epoch 94/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: -0.0184 - g_loss: 7.3043 - imp_loss: 3.0740 - seis_loss: 0.16580s - d_loss: 0.0149 - g_loss: 5.3766 - imp_loss: 2.8156 - seis_loss: 0.168 - ETA: 0s - d_loss: 0.0011 - g_loss: 6.1080 - imp_loss: 2.8722 - seis_loss:
# Epoch 95/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0095 - g_loss: 2.0726 - imp_loss: 2.7404 - seis_loss: 0.15881s - d_loss: -0.0492 - g_loss: 7.5557 - imp_loss: 2.9111 -
# Epoch 96/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0146 - g_loss: -0.6842 - imp_loss: 3.0037 - seis_loss: 0.15831s - d_loss: 0.0946 - g_loss: -8.8017 - imp_loss: 2.6991 - seis_los - ETA: 0s - d_loss: 0.0603 - g_loss: -7.4137 - imp_loss: 2.8134 - seis_loss
# Epoch 97/2000
# 11/11 [==============================] - 3s 279ms/step - d_loss: 5.8393e-04 - g_loss: 6.3521 - imp_loss: 2.6726 - seis_loss: 0.1574- d_loss: 0.0227 - g_loss: 14.7462 - imp_loss: 2.8333 - seis
# Epoch 98/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0391 - g_loss: 2.0317 - imp_loss: 3.7419 - seis_loss: 0.1577: 1s - d_loss: -0.0042 - g_loss: -5.1053 - imp_loss: 2.5929 - seis_loss: 0.165 - ETA: 1s - d_loss: -0.0050 - g_loss: -4.5518 - imp_loss: 2.6323 - seis_loss: 0.16 - ETA: 0s - d_loss: -0.0042 - g_loss: -2.9894 - imp_loss: 2.7152 - seis_loss: 0.161 - ETA: 0s - d_loss: 8.7463e-04 - g_loss: -2.0338 - imp_loss: 2.7822 - seis_loss: 0. - ETA: 0s - d_loss: -0.0050 - g_loss: -0.6749 - imp_loss: 2.7756 - seis_loss: 0.157
# Epoch 99/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0463 - g_loss: 6.3547 - imp_loss: 3.3867 - seis_loss: 0.1571 1s - d_loss: 0.0626 - g_loss: 12.4072 - imp_loss: 3.9217 - seis_loss: 0. - ETA: 1s - d_loss: 0.0662 - g_loss: 13.1589 - imp_loss: 3.3748 - seis_loss: 0. - ETA: 0s - d_loss: 0.0890 - g_loss: 9.5647 - imp_loss: 3.4974 - seis_loss: 0.
# Epoch 100/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0544 - g_loss: 2.4544 - imp_loss: 4.0418 - seis_loss: 0.1632
# Epoch 101/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0168 - g_loss: 1.8956 - imp_loss: 3.4859 - seis_loss: 0.1595 1s - d_loss: 0.0799 - g_loss: 1.3849 - imp_loss: 3.8400 - seis_loss: 0 - ETA: 0s - d_loss: 0.0471 - g_loss: 1.1961 - imp_loss: 3.6807 - seis_loss: 0.163 - ETA: 0s - d_loss: 0.0400 - g_loss: 0.8480 - imp_loss: 3.5897 - seis_loss: 0.16 - ETA: 0s - d_loss: 0.0362 - g_loss: 1.2910 - imp_loss: 3.6891 - seis_loss: 0.16
# Epoch 102/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: -0.0561 - g_loss: 1.8940 - imp_loss: 2.7923 - seis_loss: 0.15401s - d_loss: 0.0080 - g_loss: 7.2543 - imp_loss: 2.5341 - seis_loss: 0.161 - ETA: 1s - d_loss: 0.0041 - g_loss: 5.9556 - imp_loss: 2.4469 - seis_loss: 0.160 - ETA: 0s - d_loss: 0.0071 - g_loss: 4.8056 - imp_loss: 2.4403 - seis_lo
# Epoch 103/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0440 - g_loss: 3.0087 - imp_loss: 2.6217 - seis_loss: 0.1523 1s - d_loss: 0.0097 - g_loss: 2.9932 - imp_loss: 2.8747 - seis_loss: 0.1 - ETA: 0s - d_loss: 0.0282 - g_loss: 3.0542 - imp_loss: 2.7515 - seis_loss: 0
# Epoch 104/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0295 - g_loss: 4.7817 - imp_loss: 2.4248 - seis_loss: 0.1473 1s - d_loss: 0.1431 - g_loss: 3.8232 - imp_loss: 2.7245 - seis_loss: 0.150 - ETA: 1s - d_loss: 0.0937 - g_loss: 4.4691 - imp_loss: 2.7307 - seis_loss: 0. - ETA: 0s - d_loss: 0.0593 - g_loss: 3.8438 - imp_loss: 2.6939 - seis_loss: 0
# Epoch 105/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0318 - g_loss: 0.2033 - imp_loss: 2.3434 - seis_loss: 0.1436 1s - d_loss: 0.0351 - g_loss: 8.8830 - imp_loss: 2.2825 - seis_loss:  - ETA: 0s - d_loss: 0.0219 - g_loss: 2.8620 - imp_loss: 2.4790 - seis_loss: 0.14 - ETA: 0s - d_loss: 0.0138 - g_loss: 1.0395 - imp_loss: 2.5171 - seis_loss: 0.14
# Epoch 106/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: -0.0094 - g_loss: 7.3645 - imp_loss: 2.5885 - seis_loss: 0.1436: 1s - d_loss: 0.0117 - g_loss: 0.4172 - imp_loss: 2.4033 - seis_lo
# Epoch 107/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0062 - g_loss: 2.3786 - imp_loss: 2.4369 - seis_loss: 0.13901s - d_loss: 0.0395 - g_loss: 3.0619 - imp_loss: 2.3232 - seis_loss: 0.142 - ETA: 0s - d_loss: 0.0286 - g_loss: 2.3665 - imp_loss: 2.2660 - seis_loss: 0.14 - ETA: 0s - d_loss: 0.0118 - g_loss: 2.1112 - imp_loss: 2.3062 - seis_loss: 0.141 - ETA: 0s - d_loss: 0.0039 - g_loss: 2.1528 - imp_loss: 2.4252 - seis_loss: 0.
# Epoch 108/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0126 - g_loss: 6.3613 - imp_loss: 2.2157 - seis_loss: 0.13811s - d_loss: -0.0216 - g_loss: 4.4044 - imp_loss: 2.6591 - seis_loss:  - ETA: 0s - d_loss: -0.0075 - g_loss: 5.5675 - imp_loss: 2.5574 - seis_loss: 0.13 - ETA: 0s - d_loss: -0.0099 - g_loss: 6.2524 - imp_loss: 2.5502 - seis_loss:
# Epoch 109/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0023 - g_loss: 2.7288 - imp_loss: 3.2285 - seis_loss: 0.13821s - d_loss: 0.0070 - g_loss: 4.7455 - imp_loss: 3.2843 - seis_loss: 0.1 - ETA: 1s - d_loss: -0.0087 - g_loss: 3.1921 - imp_loss: 2.7541 - seis_loss: 0. - ETA: 0s - d_loss: -0.0244 - g_loss: 5.3956 - imp_loss: 2.7135 - seis_loss: 0. - ETA: 0s - d_loss: -0.0165 - g_loss: 6.9198 - imp_loss: 2.6768 - seis_loss
# Epoch 110/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0320 - g_loss: 5.2173 - imp_loss: 2.5712 - seis_loss: 0.13711s - d_loss: 0.0753 - g_loss: -5.2343 - imp_loss: 2.2766 - seis_loss: 0.13 - ETA: 1s - d_loss: 0.0422 - g_loss: -4.1102 - imp_loss: 2.5063 - sei
# Epoch 111/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.0323 - g_loss: -1.1114 - imp_loss: 2.7404 - seis_loss: 0.14241s - d_loss: 0.2454 - g_loss: 5.4267 - imp_loss: 2.8469 - seis_loss: 0.149 - ETA: 1s - d_loss: 0.1768 - g_loss: 3.7639 - imp_loss: 3.1133 - seis_loss: 0. - ETA: 0s - d_loss: 0.0979 - g_loss: -1.2962 - imp_loss: 2.6815 - seis_
# Epoch 112/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0540 - g_loss: 10.2764 - imp_loss: 2.3579 - seis_loss: 0.14051s - d_loss: -0.0330 - g_loss: 8.2835 - imp_loss: 2.6431
# Epoch 113/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0211 - g_loss: 11.1576 - imp_loss: 2.5264 - seis_loss: 0.1330 0s - d_loss: -0.0059 - g_loss: 11.2399 - imp_loss: 2.3063 - seis_loss: 0.134 - ETA: 0s - d_loss: -0.0169 - g_loss: 11.2738 - imp_loss: 2.3351 - seis_loss: 0.1
# Epoch 114/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0249 - g_loss: 14.4197 - imp_loss: 2.3728 - seis_loss: 0.13351s - d_loss: 0.0395 - g_loss: 12.0482 - imp_loss: 2.1986 - seis_lo - ETA: 0s - d_loss: 0.0298 - g_loss: 13.6295 - imp_loss: 2.4056 - seis_loss: 0.
# Epoch 115/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0135 - g_loss: 12.9553 - imp_loss: 2.3066 - seis_loss: 0.1352s - d_loss: 0.1150 - g_loss: 25.0306 - imp_loss: 2.6379 - seis_loss - ETA: 0s - d_loss: 0.0160 - g_loss: 22.6661 - imp_loss: 2.4819 - seis_los
# Epoch 116/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: -0.0014 - g_loss: 0.9887 - imp_loss: 2.2601 - seis_loss: 0.1319: 1s - d_loss: 0.0328 - g_loss: -10.7421 - imp_loss: 2.5322 - seis_lo
# Epoch 117/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0958 - g_loss: 6.8452 - imp_loss: 2.9114 - seis_loss: 0.13300s - d_loss: -0.0137 - g_loss: 6.1706 - imp_loss: 2.4969 - seis_loss: 0.
# Epoch 118/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0120 - g_loss: 14.0243 - imp_loss: 2.1322 - seis_loss: 0.13121s - d_loss: 0.0255 - g_loss: 10.6402 - imp_loss: 2.0490 - seis_los - ETA: 0s - d_loss: 0.0189 - g_loss: 16.7519 - imp_loss: 2.3669 - seis_loss: 0.12 - ETA: 0s - d_loss: 0.0212 - g_loss: 15.9852 - imp_loss: 2.3365 - seis_loss: 0.
# Epoch 119/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: -0.0994 - g_loss: 6.3135 - imp_loss: 3.1009 - seis_loss: 0.13341s - d_loss: -0.0183 - g_loss: -2.0287 - imp_loss: 2.4854 - seis_loss: 0. - ETA: 0s - d_loss: -0.0442 - g_loss: -4.3201 - imp_loss: 2.4149 - seis_loss: 0.13 - ETA: 0s - d_loss: -0.0449 - g_loss: -1.4853 - imp_loss: 2.5567 - seis_loss: 0.132 - ETA: 0s - d_loss: -0.0495 - g_loss: 0.4094 - imp_loss: 2.5151 - seis_loss: 0
# Epoch 120/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0752 - g_loss: 1.7805 - imp_loss: 3.3376 - seis_loss: 0.1403: 0s - d_loss: 0.1024 - g_loss: 7.2629 - imp_loss: 3.1037 - seis_loss: 0.145 - ETA: 0s - d_loss: 0.0984 - g_loss: 5.2467 - imp_loss: 3.2388 - seis_loss: 0.
# Epoch 121/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0091 - g_loss: 11.2579 - imp_loss: 2.5070 - seis_loss: 0.12751s - d_loss: 0.0504 - g_loss: 3.4402 - imp_loss: 2.3946 - seis_loss: 0.1 - ETA: 0s - d_loss: 0.0251 - g_loss: 7.2922 - imp_loss: 2.2607 - seis_loss: 0
# Epoch 122/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0101 - g_loss: 6.9859 - imp_loss: 2.7193 - seis_loss: 0.1344 0s - d_loss: 0.0504 - g_loss: 9.9378 - imp_loss: 2.3691 - seis_loss: 0.1334 - ETA: 0s - d_loss: 0.0380 - g_loss: 8.3165 - imp_loss: 2.3995 - seis_loss: 0.
# Epoch 123/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0339 - g_loss: 6.4719 - imp_loss: 2.3571 - seis_loss: 0.1280 1s - d_loss: 0.0751 - g_loss: 9.4169 - imp_loss: 2.0573 - seis_loss: 0.129 - ETA: 1s - d_loss: 0.0636 - g_loss: 9.4220 - imp_loss: 2.0705 - seis_loss: 0 - ETA: 0s - d_loss: 0.0381 - g_loss: 7.1394 - imp_loss: 2.2315 - seis_loss: 0.12
# Epoch 124/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0553 - g_loss: 11.2298 - imp_loss: 2.3433 - seis_loss: 0.12571s - d_loss: 0.1059 - g_loss: 4.6643 - imp_loss: 1.9805 - seis_loss: 0.123 - ETA: 1s - d_loss: 0.0679 - g_loss: 6.5738 - imp_loss: 2.1759 - seis_loss: 0.12 - ETA: 1s - d_loss: 0.0619 - g_loss: 10.7384 - imp_loss: 2.2502 - seis_loss - ETA: 0s - d_loss: 0.0170 - g_loss: 12.1003 - imp_loss: 2.3006 - seis_loss:
# Epoch 125/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: -0.0022 - g_loss: 2.6211 - imp_loss: 2.0950 - seis_loss: 0.12301s - d_loss: 0.2488 - g_loss: 5.7820 - imp_loss: 2.6525 - seis_loss: 0.13 - ETA: 1s - d_loss: 0.1175 - g_loss: 3.1917 - imp_loss: 2.2529 - seis_loss: 0.1 - ETA: 0s - d_loss: 0.0450 - g_loss: 1.1546 - imp_loss: 2.1385 - seis_loss: 0.12 - ETA: 0s - d_loss: 0.0217 - g_loss: 1.2643 - imp_loss: 2.1077 - seis_loss: 0.125 - ETA: 0s - d_loss: 0.0189 - g_loss: 1.7136 - imp_loss: 2.1233 - seis_loss: 0.12
# Epoch 126/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0278 - g_loss: 8.2865 - imp_loss: 2.1475 - seis_loss: 0.1194 1s - d_loss: -0.0161 - g_loss: 11.1996 - imp_loss: 1.6784 - seis_loss: 0.11 - ETA: 1s - d_loss: 8.6237e-04 - g_loss: 12.0110 - imp_loss: 1.9010 - seis_loss: 0. - ETA: 0s - d_loss: 8.7660e-04 - g_loss: 10.7698 - imp_loss: 1.9553 - seis_loss: 0.1 - ETA: 0s - d_loss: -0.0028 - g_loss: 9.4485 - imp_loss: 2.0680 - seis_loss: 0.
# Epoch 127/2000
# 11/11 [==============================] - 2s 186ms/step - d_loss: -0.0048 - g_loss: 1.9636 - imp_loss: 2.0554 - seis_loss: 0.11941s - d_loss: -0.0190 - g_loss: 8.9076 - imp_loss: 2.0773 - seis_loss:  - ETA: 0s - d_loss: -0.0195 - g_loss: 7.9668 - imp_loss: 2.0732 - seis_loss
# Epoch 128/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0142 - g_loss: 0.9254 - imp_loss: 2.6312 - seis_loss: 0.1177A: 1s - d_loss: 0.0040 - g_loss: -9.0040 - imp_loss: 2.0324 - seis_loss:
# Epoch 129/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0020 - g_loss: 14.6039 - imp_loss: 2.0245 - seis_loss: 0.1169
# Epoch 130/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0430 - g_loss: 6.6927 - imp_loss: 2.3704 - seis_loss: 0.1184
# Epoch 131/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: -0.0207 - g_loss: 3.6222 - imp_loss: 2.5317 - seis_loss: 0.12131s - d_loss: 0.0027 - g_loss: 8.3655 - imp_loss: 2.4209 - seis_loss - ETA: 0s - d_loss: -0.0275 - g_loss: 9.3751 - imp_loss: 2.4102 - seis_loss: 0
# Epoch 132/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.1318 - g_loss: -4.2077 - imp_loss: 2.3486 - seis_loss: 0.1173: 0s - d_loss: 0.2091 - g_loss: -17.6901 - imp_loss: 2.3966 - seis_loss: 0.1 - ETA: 0s - d_loss: 0.1345 - g_loss: -11.9950 - imp_loss: 2.4048 - seis_loss: 0
# Epoch 133/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0562 - g_loss: 5.9490 - imp_loss: 2.0904 - seis_loss: 0.1177 0s - d_loss: 0.1086 - g_loss: 16.6599 - imp_loss: 2.1473 - seis_loss:  - ETA: 0s - d_loss: 0.0574 - g_loss: 9.5229 - imp_loss: 2.1229 - seis_loss: 0.118
# Epoch 134/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0117 - g_loss: -2.4280 - imp_loss: 1.9849 - seis_loss: 0.11591s - d_loss: 0.1487 - g_loss: -12.0649 - imp_loss: 2.2889 - seis_loss: 0.11 - ETA: 1s - d_loss: 0.1283 - g_loss: -13.3093 - imp_loss: 2.0854 - seis
# Epoch 135/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: -0.0276 - g_loss: 0.6441 - imp_loss: 1.8436 - seis_loss: 0.11501s - d_loss: 0.0047 - g_loss: 9.0776 - imp_loss: 2.1113 - seis_loss: 0.120 - ETA: 1s - d_loss: -0.0027 - g_loss: 5.4646 - imp_loss: 2.0736 - s
# Epoch 136/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.0103 - g_loss: 3.4768 - imp_loss: 1.9995 - seis_loss: 0.1136 0s - d_loss: 0.0106 - g_loss: 3.8261 - imp_loss: 2.1147 - seis_loss:
# Epoch 137/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 7.6917e-04 - g_loss: 8.4142 - imp_loss: 2.5083 - seis_loss: 0.1095 - d_loss: -0.0156 - g_loss: 6.1134 - imp_loss: 1.8243 - seis_loss: 0.10 - ETA: 1s - d_loss: -0.0232 - g_loss: 6.1378 - imp_loss: 1.8789 - seis_loss - ETA: 0s - d_loss: -0.0295 - g_loss: 6.7616 - imp_loss: 1.9206 - seis_loss
# Epoch 138/2000
# 11/11 [==============================] - 2s 182ms/step - d_loss: 0.1316 - g_loss: 16.3955 - imp_loss: 2.4022 - seis_loss: 0.11221s - d_loss: 0.1703 - g_loss: 11.7525 - imp_loss: 2.3562 - seis_loss - ETA: 0s - d_loss: 0.1318 - g_loss: 19.8347 - imp_loss: 2.3862 - seis_loss: 0. - ETA: 0s - d_loss: 0.1137 - g_loss: 20.2381 - imp_loss: 2.3260 - seis_loss
# Epoch 139/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0775 - g_loss: -1.5971 - imp_loss: 2.2279 - seis_loss: 0.11081s - d_loss: 0.1488 - g_loss: 3.9738 - imp_loss: 2.1941 - seis_loss: 0.110 - ETA: 1s - d_loss: 0.1609 - g_loss: 3.3804 - imp_loss: 2.3837 - seis_loss: 0.11 - ETA: 1s - d_loss: 0.1391 - g_loss: 1.5508 - imp_loss: 2.4267 - seis_loss: 0.110 - ETA: 0s - d_loss: 0.1232 - g_loss: 0.5849 - imp_loss: 2.2643 - seis_loss: 0 - ETA: 0s - d_loss: 0.0840 - g_loss: -1.1207 - imp_loss: 2.1292 - seis_loss: 0.11 - ETA: 0s - d_loss: 0.0741 - g_loss: -1.3916 - imp_loss: 2.1101 - seis_loss: 0.
# Epoch 140/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.1794 - g_loss: 15.1240 - imp_loss: 2.5584 - seis_loss: 0.11271s - d_loss: 0.5840 - g_loss: -0.4976 - imp_loss: 2.0519 - seis_loss: 0. - ETA: 1s - d_loss: 0.4390 - g_loss: 4.1054 - imp_loss: 2.2359 - seis_l
# Epoch 141/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0523 - g_loss: 9.4266 - imp_loss: 2.3904 - seis_loss: 0.1144 1s - d_loss: 0.1728 - g_loss: 25.1916 - imp_loss: 2.7665 - seis_lo - ETA: 0s - d_loss: 0.0523 - g_loss: 12.3221 - imp_loss: 2.8598 - seis_loss:
# Epoch 142/2000
# 11/11 [==============================] - 2s 184ms/step - d_loss: 0.0031 - g_loss: 13.4636 - imp_loss: 2.2712 - seis_loss: 0.11271s - d_loss: -0.0404 - g_loss: 9.0863 - imp_loss: 2.6774 - seis_loss: 0. - ETA: 1s - d_loss: 0.0280 - g_loss: 11.1435 - imp_loss: 2.5951 - seis_loss: 0. - ETA: 0s - d_loss: 0.0347 - g_loss: 13.6463 - imp_loss: 2.4903 - seis_loss: 0. - ETA: 0s - d_loss: 8.6738e-04 - g_loss: 14.2711 - imp_loss: 2.5126 - seis_loss: 0.1 - ETA: 0s - d_loss: -0.0117 - g_loss: 13.9131 - imp_loss: 2.3459 - seis_loss: 0.11
# Epoch 143/2000
# ...
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0622 - g_loss: -51.2514 - imp_loss: 0.1338 - seis_loss: 0.0117 1s - d_loss: 0.0898 - g_loss: -32.0094 - imp_loss: 0.1225 - seis_loss: 0.01 - ETA: 1s - d_loss: 0.0802 - g_loss: -31.1106 - imp_loss: 0.1271 - seis_loss: 0.011 - ETA: 0s - d_loss: 0.0709 - g_loss: -32.1349 - imp_loss: 0.1254 - seis_loss: 0. - ETA: 0s - d_loss: 0.0666 - g_loss: -42.9559 - imp_loss: 0.1312 - seis_loss: 0.01
# Epoch 1960/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0395 - g_loss: -73.1384 - imp_loss: 0.1625 - seis_loss: 0.0113 1s - d_loss: 0.0272 - g_loss: -129.8445 - imp_loss: 0.0870 - seis_loss: 0.01 - ETA: 1s - d_loss: 0.0309 - g_loss: -127.8431 - imp_loss: 0.1006 - sei
# Epoch 1961/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0469 - g_loss: -62.0543 - imp_loss: 0.1056 - seis_loss: 0.0107 1s - d_loss: 0.0644 - g_loss: -29.7477 - imp_loss: 0.0923 - seis_loss:  - ETA: 0s - d_loss: 0.0492 - g_loss: -50.1620 - imp_loss: 0.1044 - seis_loss: 0.
# Epoch 1962/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0456 - g_loss: -46.5500 - imp_loss: 0.1200 - seis_loss: 0.0101 1s - d_loss: 0.0449 - g_loss: -90.8053 - imp_loss: 0.1134 - seis_loss: 0.010 - ETA: 1s - d_loss: 0.0512 - g_loss: -91.3986 - imp_loss: 0.1505 - seis_loss: 0.010 - ETA: 1s - d_loss: 0.0537 - g_loss: -92.5287 - imp_loss: 0.1389 - seis_loss
# Epoch 1963/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0586 - g_loss: -69.4598 - imp_loss: 0.1324 - seis_loss: 0.0099 0s - d_loss: 0.0525 - g_loss: -50.8957 - imp_loss: 0.1101 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0540 - g_loss: -61.7257 - imp_loss: 0.1123 - seis_loss: 0.01
# Epoch 1964/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0714 - g_loss: -53.7889 - imp_loss: 0.1108 - seis_loss: 0.0099 1s - d_loss: 0.0826 - g_loss: -120.3912 - imp_loss: 0.1058 - seis_loss: 0. - ETA: 1s - d_loss: 0.0756 - g_loss: -103.9790 - imp_loss: 0.1093 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0705 - g_loss: -86.7787 - imp_loss: 0.1158 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0658 - g_loss: -65.3650 - imp_loss: 0.1168 - seis_loss: 0.01
# Epoch 1965/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0647 - g_loss: -51.9690 - imp_loss: 0.1456 - seis_loss: 0.0099s - d_loss: 0.0727 - g_loss: 2.1994 - imp_loss: 0.1409 - seis_loss: 0.0 - ETA: 1s - d_loss: 0.0741 - g_loss: -6.5025 - imp_loss: 0.1273 - seis_loss: 0 - ETA: 0s - d_loss: 0.0687 - g_loss: -32.1592 - imp_loss: 0.1418 - seis_loss: 0.0
# Epoch 1966/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0771 - g_loss: -24.3671 - imp_loss: 0.1241 - seis_loss: 0.0100 1s - d_loss: 0.1049 - g_loss: -126.7895 - imp_loss: 0.1195 - seis_loss: 0 - ETA: 1s - d_loss: 0.0911 - g_loss: -83.0711 - imp_loss: 0.1205 - seis_loss: 0.010 - ETA: 0s - d_loss: 0.0879 - g_loss: -69.7023 - imp_loss: 0.1244 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0780 - g_loss: -37.2265 - imp_loss: 0.1273 - seis_loss: 0.0
# Epoch 1967/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0894 - g_loss: -68.4193 - imp_loss: 0.1353 - seis_loss: 0.0097 1s - d_loss: 0.0955 - g_loss: -18.3919 - imp_loss: 0.1124 - seis_loss: 0.00 - ETA: 1s - d_loss: 0.1041 - g_loss: -33.7598 - imp_loss: 0.1276 - seis_loss: 0.009 - ETA: 1s - d_loss: 0.0974 - g_loss: -45.2060 - imp_loss: 0.1256 - seis_loss:
# Epoch 1968/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0740 - g_loss: -16.1483 - imp_loss: 0.1716 - seis_loss: 0.0101 1s - d_loss: 0.0729 - g_loss: -44.5178 - imp_loss: 0.1375 - seis_loss: 0. - ETA: 0s - d_loss: 0.0671 - g_loss: -20.0032 - imp_loss: 0.1389 - seis_loss: 0
# Epoch 1969/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0837 - g_loss: -59.9867 - imp_loss: 0.1622 - seis_loss: 0.0108s - d_loss: 0.1095 - g_loss: -10.4372 - imp_loss: 0.1697 - seis_loss: 0.011 - ETA: 1s - d_loss: 0.0996 - g_loss: -16.7267 - imp_loss: 0.1564 - seis_loss:  - ETA: 0s - d_loss: 0.0872 - g_loss: -57.3683 - imp_loss: 0.1611 - seis_loss: 0.01
# Epoch 1970/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0851 - g_loss: -1.2473 - imp_loss: 0.2310 - seis_loss: 0.0104: 1s - d_loss: 0.0797 - g_loss: -41.6428 - imp_loss: 0.2436 - sei
# Epoch 1971/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0927 - g_loss: -48.3888 - imp_loss: 0.1863 - seis_loss: 0.0103 0s - d_loss: 0.1010 - g_loss: -59.5783 - imp_loss: 0.1974 - seis_loss: 0.010 - ETA: 0s - d_loss: 0.0987 - g_loss: -59.6588 - imp_loss: 0.1916 - seis_loss: 0.0
# Epoch 1972/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0913 - g_loss: 20.0268 - imp_loss: 0.2000 - seis_loss: 0.01031s - d_loss: 0.0907 - g_loss: 32.3996 - imp_loss: 0.2188 - s
# Epoch 1973/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.1040 - g_loss: -46.1440 - imp_loss: 0.2193 - seis_loss: 0.0115
# Epoch 1974/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0815 - g_loss: 24.4872 - imp_loss: 0.1945 - seis_loss: 0.01170s - d_loss: 0.0942 - g_loss: 40.3589 - imp_loss: 0.2279 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0922 - g_loss: 37.7300 - imp_loss: 0.2116 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0902 - g_loss: 33.7328 - imp_loss: 0.2016 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0891 - g_loss: 30.6832 - imp_loss: 0.2034 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0883 - g_loss: 28.0484 - imp_loss: 0.2013 - seis_loss: 0.
# Epoch 1975/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0695 - g_loss: -41.2500 - imp_loss: 0.1718 - seis_loss: 0.0104 1s - d_loss: 0.0851 - g_loss: -33.6985 - imp_loss: 0.2070 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0775 - g_loss: -53.6657 - imp_loss: 0.1801 - seis_loss: 0. - ETA: 0s - d_loss: 0.0760 - g_loss: -46.6799 - imp_loss: 0.1803 - seis_loss: 0.01
# Epoch 1976/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0652 - g_loss: 35.4152 - imp_loss: 0.1903 - seis_loss: 0.0108 1s - d_loss: 0.0801 - g_loss: 6.5278 - imp_loss: 0.2283 - seis_loss: 0.010 - ETA: 1s - d_loss: 0.0792 - g_loss: 15.1957 - imp_loss: 0.2647 - s
# Epoch 1977/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.1198 - g_loss: -43.9193 - imp_loss: 0.1559 - seis_loss: 0.0109s - d_loss: 0.1052 - g_loss: -6.0915 - imp_loss: 0.1480 - seis_l
# Epoch 1978/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0754 - g_loss: -17.7514 - imp_loss: 0.1172 - seis_loss: 0.0106 1s - d_loss: 0.0982 - g_loss: -68.8036 - imp_loss: 0.1372 - seis_loss: 0.010 - ETA: 1s - d_loss: 0.0923 - g_loss: -64.5589 - imp_loss: 0.1315 - seis_loss: 0 - ETA: 0s - d_loss: 0.0787 - g_loss: -31.7394 - imp_loss: 0.1264 - seis_loss: 0.01
# Epoch 1979/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0559 - g_loss: 15.9132 - imp_loss: 0.1157 - seis_loss: 0.01031s - d_loss: 0.0619 - g_loss: 44.1793 - imp_loss: 0.1235 - sei
# Epoch 1980/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0596 - g_loss: -36.0038 - imp_loss: 0.1396 - seis_loss: 0.0106 1s - d_loss: 0.0645 - g_loss: -58.2709 - imp_loss: 0.1172 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0651 - g_loss: -58.3352 - imp_loss: 0.1211 - seis_loss: 0.010 - ETA: 0s - d_loss: 0.0640 - g_loss: -55.7562 - imp_loss: 0.1222 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0632 - g_loss: -43.9620 - imp_loss: 0.1205 - seis_loss: 0.01
# Epoch 1981/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0611 - g_loss: 33.2075 - imp_loss: 0.1517 - seis_loss: 0.01071s - d_loss: 0.0642 - g_loss: 20.0188 - imp_loss: 0.1345 - seis_loss: 0. - ETA: 0s - d_loss: 0.0645 - g_loss: 23.7934 - imp_loss: 0.1346 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0657 - g_loss: 25.0226 - imp_loss: 0.1434 - seis_lo
# Epoch 1982/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0750 - g_loss: -20.1225 - imp_loss: 0.1343 - seis_loss: 0.0103s - d_loss: 0.0775 - g_loss: -4.6811 - imp_loss: 0.1369 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0758 - g_loss: -9.3113 - imp_loss: 0.1320 - seis_loss: 0. - ETA: 0s - d_loss: 0.0769 - g_loss: -20.9431 - imp_loss: 0.1312 - seis_loss: 0.0
# Epoch 1983/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0917 - g_loss: 36.8023 - imp_loss: 0.1682 - seis_loss: 0.01001s - d_loss: 0.1156 - g_loss: 30.9742 - imp_loss: 0.1133 - seis_loss: 0. - ETA: 1s - d_loss: 0.0967 - g_loss: 40.6121 - imp_loss: 0.1276 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0882 - g_loss: 43.3219 - imp_loss: 0.1220 - seis_loss:  - ETA: 0s - d_loss: 0.0782 - g_loss: 42.4827 - imp_loss: 0.1151 - seis_loss:
# Epoch 1984/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0664 - g_loss: -24.7173 - imp_loss: 0.2033 - seis_loss: 0.0115s - d_loss: 0.0776 - g_loss: -0.1394 - imp_loss: 0.1603 - seis_loss: 0. - ETA: 1s - d_loss: 0.0719 - g_loss: -8.3681 - imp_loss: 0.1652 - seis_loss: 0. - ETA: 0s - d_loss: 0.0708 - g_loss: -18.8424 - imp_loss: 0.1715 - seis_loss: 0.011 - ETA: 0s - d_loss: 0.0707 - g_loss: -20.4677 - imp_loss: 0.1684 - seis_loss: 0.0
# Epoch 1985/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0611 - g_loss: 19.1094 - imp_loss: 0.1710 - seis_loss: 0.0114: 1s - d_loss: 0.0720 - g_loss: 3.0953 - imp_loss: 0.1841 - seis_loss: 0.0117  - ETA: 1s - d_loss: 0.0692 - g_loss: 11.0906 - imp_loss: 0.1836 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0686 - g_loss: 17.1428 - imp_loss: 0.1768 - seis_loss - ETA: 0s - d_loss: 0.0684 - g_loss: 20.7120 - imp_loss: 0.1646 - seis_loss: 0.
# Epoch 1986/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0720 - g_loss: -35.3997 - imp_loss: 0.1429 - seis_loss: 0.0123s - d_loss: 0.0644 - g_loss: -2.1084 - imp_loss: 0.1393 - seis_loss: 0 - ETA: 1s - d_loss: 0.0650 - g_loss: -21.4291 - imp_loss: 0.1396 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0708 - g_loss: -33.4571 - imp_loss: 0.1575 - seis_loss: 0
# Epoch 1987/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0770 - g_loss: 30.6426 - imp_loss: 0.1423 - seis_loss: 0.01061s - d_loss: 0.0929 - g_loss: 4.4274 - imp_loss: 0.1220 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0890 - g_loss: 16.1393 - imp_loss: 0.1329 - seis_loss:  - ETA: 0s - d_loss: 0.0867 - g_loss: 26.4316 - imp_loss: 0.1320 - seis_loss: 0.
# Epoch 1988/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0928 - g_loss: 9.5385 - imp_loss: 0.1736 - seis_loss: 0.0109 1s - d_loss: 0.0895 - g_loss: 30.3934 - imp_loss: 0.1747 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0893 - g_loss: 27.0331 - imp_loss: 0.1774 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.0896 - g_loss: 23.2241 - imp_loss: 0.1789 - seis_loss: 0. - ETA: 0s - d_loss: 0.0900 - g_loss: 15.8723 - imp_loss: 0.1783 - seis_loss:
# Epoch 1989/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0949 - g_loss: 8.9294 - imp_loss: 0.1582 - seis_loss: 0.0104 1s - d_loss: 0.1185 - g_loss: 0.1236 - imp_loss: 0.1756 - seis_loss: 0.010 - ETA: 0s - d_loss: 0.1098 - g_loss: 4.4766 - imp_loss: 0.1692 - seis_loss: 0.010 - ETA: 0s - d_loss: 0.1075 - g_loss: 6.1895 - imp_loss: 0.1686 - seis_loss: 0.010 - ETA: 0s - d_loss: 0.1033 - g_loss: 7.3948 - imp_loss: 0.1677 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.1015 - g_loss: 8.6832 - imp_loss: 0.1640 - seis_loss: 0.01
# Epoch 1990/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0940 - g_loss: -3.3007 - imp_loss: 0.1498 - seis_loss: 0.00961s - d_loss: 0.1115 - g_loss: 10.0482 - imp_loss: 0.1502 - seis_loss: 0.00 - ETA: 1s - d_loss: 0.1138 - g_loss: 8.2279 - imp_loss: 0.1578 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.1034 - g_loss: 1.8067 - imp_loss: 0.1589 - seis_loss: 0.009 - ETA: 0s - d_loss: 0.1015 - g_loss: 0.5667 - imp_loss: 0.1606 - seis_loss: 0
# Epoch 1991/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0931 - g_loss: -6.2623 - imp_loss: 0.1593 - seis_loss: 0.0095: 1s - d_loss: 0.1148 - g_loss: -15.2309 - imp_loss: 0.1788 - seis_lo - ETA: 0s - d_loss: 0.0925 - g_loss: -7.0080 - imp_loss: 0.1518 - seis_loss:
# Epoch 1992/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0905 - g_loss: 12.4229 - imp_loss: 0.1430 - seis_loss: 0.00991s - d_loss: 0.0870 - g_loss: 3.9369 - imp_loss: 0.1330 - seis_loss: 0.009 - ETA: 0s - d_loss: 0.0889 - g_loss: 5.5849 - imp_loss: 0.1393 - seis_loss
# Epoch 1993/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.1056 - g_loss: 39.9745 - imp_loss: 0.1414 - seis_loss: 0.00951s - d_loss: 0.1218 - g_loss: 26.0686 - imp_loss: 0.1448 - seis_loss: 0.00 - ETA: 1s - d_loss: 0.1220 - g_loss: 25.9286 - imp_loss: 0.1531 - seis_loss: 0.00 - ETA: 1s - d_loss: 0.1165 - g_loss: 26.8851 - imp_loss: 0.1455 - seis_loss:  - ETA: 0s - d_loss: 0.1047 - g_loss: 31.8653 - imp_loss: 0.1424 - seis_loss: 0.00 - ETA: 0s - d_loss: 0.1046 - g_loss: 33.0236 - imp_loss: 0.1398 - seis_loss: 0.00 - ETA: 0s - d_loss: 0.1006 - g_loss: 35.4645 - imp_loss: 0.1391 - seis_loss: 0.
# Epoch 1994/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0853 - g_loss: 52.4717 - imp_loss: 0.1132 - seis_loss: 0.00941s - d_loss: 0.0998 - g_loss: 77.5890 - imp_loss: 0.1123 - seis_loss: 0. - ETA: 0s - d_loss: 0.0975 - g_loss: 70.6850 - imp_loss: 0.1218 - seis_loss: 0. - ETA: 0s - d_loss: 0.0919 - g_loss: 63.1857 - imp_loss: 0.1216 - seis_loss:
# Epoch 1995/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0780 - g_loss: 8.6216 - imp_loss: 0.0997 - seis_loss: 0.0095 1s - d_loss: 0.0826 - g_loss: 9.0712 - imp_loss: 0.1028 - seis_loss: 0.0 - ETA: 0s - d_loss: 0.0864 - g_loss: 7.2534 - imp_loss: 0.1048 - seis_loss: 0.009 - ETA: 0s - d_loss: 0.0836 - g_loss: 7.5819 - imp_loss: 0.1027 - seis_loss: 0.0
# Epoch 1996/2000
# 11/11 [==============================] - 2s 183ms/step - d_loss: 0.0867 - g_loss: 33.6092 - imp_loss: 0.1215 - seis_loss: 0.00911s - d_loss: 0.0963 - g_loss: 16.1368 - imp_loss: 0.0887 - seis_loss: 0. - ETA: 1s - d_loss: 0.0947 - g_loss: 19.0000 - imp_loss: 0.0948 - seis_loss: 0. - ETA: 0s - d_loss: 0.0887 - g_loss: 22.7569 - imp_loss: 0.0985 - seis_loss:  - ETA: 0s - d_loss: 0.0849 - g_loss: 29.2082 - imp_loss: 0.1010 - seis_loss: 0.00 - ETA: 0s - d_loss: 0.0836 - g_loss: 31.2250 - imp_loss: 0.1033 - seis_loss: 0.
# Epoch 1997/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0747 - g_loss: 37.0195 - imp_loss: 0.1136 - seis_loss: 0.00921s - d_loss: 0.0835 - g_loss: 50.4346 - imp_loss: 0.1193 - seis_loss: 0.00 - ETA: 1s - d_loss: 0.0787 - g_loss: 50.6966 - imp_loss: 0.1113 - seis_loss:  - ETA: 0s - d_loss: 0.0796 - g_loss: 45.6867 - imp_loss: 0.1110 - seis_loss: 0.00 - ETA: 0s - d_loss: 0.0809 - g_loss: 43.6027 - imp_loss: 0.1115 - seis_loss
# Epoch 1998/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.0791 - g_loss: 30.2775 - imp_loss: 0.1415 - seis_loss: 0.00951s - d_loss: 0.0911 - g_loss: 25.1401 - imp_loss: 0.1231 - seis_loss: 0. - ETA: 0s - d_loss: 0.0850 - g_loss: 27.2244 - imp_loss: 0.1383 - seis_loss: 0.00 - ETA: 0s - d_loss: 0.0837 - g_loss: 27.5112 - imp_loss: 0.1334 - seis_loss:  - ETA: 0s - d_loss: 0.0823 - g_loss: 28.7126 - imp_loss: 0.1339 - seis_loss: 0.
# Epoch 1999/2000
# 11/11 [==============================] - 2s 181ms/step - d_loss: 0.0795 - g_loss: 46.0297 - imp_loss: 0.2421 - seis_loss: 0.01081s - d_loss: 0.0888 - g_loss: 39.0031 - imp_loss: 0.3076 - seis_loss:  - ETA: 1s - d_loss: 0.0906 - g_loss: 42.1794 - imp_loss: 0.2705 - seis_loss:  - ETA: 0s - d_loss: 0.0880 - g_loss: 41.0972 - imp_loss: 0.2556 - seis_loss
# Epoch 2000/2000
# 11/11 [==============================] - 2s 180ms/step - d_loss: 0.1439 - g_loss: -87.8421 - imp_loss: 0.2017 - seis_loss: 0.0124 1s - d_loss: 0.1749 - g_loss: -106.3133 - imp_loss: 0.1909 - seis_loss - ETA: 0s - d_loss: 0.1619 - g_loss: -110.0963 - imp_loss: 0.2062 - seis_loss: 0.01 - ETA: 0s - d_loss: 0.1640 - g_loss: -106.5022 - imp_loss: 0.2102 - seis_loss: 0

# %%
X_predict= wgan.generator(X_test)
X_predict = np.transpose(X_predict[:,:,0,0])

# %%
fig1, axes1 = plt.subplots(nrows=2, ncols=1, figsize=(50,15))
axes1[0].imshow(X_predict)
axes1[1].imshow(np.transpose(Y_test[:,:,0,0]))

# %%
trace_id = np.random.randint(X_predict.shape[1])
plt.plot(X_predict[:,trace_id])

plt.plot(Y_test[trace_id,:,0])
plt.legend(('predicted','target'))

# %%
trace_id
# Out:
# 11885

# %%
'''# serialize model to JSON
model_json = wgan.to_json()
with open("models/model0.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
wgan.save_weights("model/model0.h5")
print("Saved model to disk")
'''
''
# Out:
# ''
